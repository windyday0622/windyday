# %% [markdown]
# <a href="https://colab.research.google.com/github/windyday0622/windyday/blob/main/m3__%EB%B6%84%EC%84%9D%20%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC/%20pandas_5_%EC%9E%85%EC%B6%9C%EB%A0%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# csv 파일 읽고 저장하기
import numpy as np
import pandas as pd
ar1 = np.arange(10).reshape(2,5)
df = pd.DataFrame(ar1,columns=list('abcde'))
df.to_csv('test.csv')

# %%
df1=df.copy()
df1
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df1.to_csv('test1.csv')
df1=pd.read_csv('test1.csv', index_col=0)
df1
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df1.iloc[0] = 2
df1.iloc[1] = 3
df1
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
# json 파일 읽고 쓰기
df1.to_json('test2.json')
df_j = pd.read_json('test2.json')
df_j
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
df1
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
# 바이너리 파일 읽고 쓰기
df1.to_pickle('test3.pkl')
df1 = pd.read_pickle('test3.pkl')
df1
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
# Q.간단한 데이터프레임 작성 후 csv, json, pickle 형태로 저장 후 다시 불러와서 출력하세요.

import pandas as pd

# 데이터프레임 생성
data = {'이름': ['철수', '영희', '민수'],
        '나이': [30, 25, 35],
        '성별': ['남', '여', '남']}

df = pd.DataFrame(data)

# CSV로 저장 후 불러오기
df.to_csv('data.csv', index=False)
df_csv = pd.read_csv('data.csv')
print("CSV 파일로 저장 후 불러오기:")
print(df_csv)

# JSON으로 저장 후 불러오기
df.to_json('data.json', orient='records')
df_json = pd.read_json('data.json')
print("\nJSON 파일로 저장 후 불러오기:")
print(df_json)

# Pickle로 저장 후 불러오기
df.to_pickle('data.pkl')
df_pickle = pd.read_pickle('data.pkl')
print("\nPickle 파일로 저장 후 불러오기:")
print(df_pickle)
# Out:
# CSV 파일로 저장 후 불러오기:
#    이름  나이 성별
# 0  철수  30  남
# 1  영희  25  여
# 2  민수  35  남
#
# JSON 파일로 저장 후 불러오기:
#    이름  나이 성별
# 0  철수  30  남
# 1  영희  25  여
# 2  민수  35  남
#
# Pickle 파일로 저장 후 불러오기:
#    이름  나이 성별
# 0  철수  30  남
# 1  영희  25  여
# 2  민수  35  남
