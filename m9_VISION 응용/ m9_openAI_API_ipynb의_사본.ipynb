# %% [markdown]
# <a href="https://colab.research.google.com/github/windyday0622/windyday/blob/main/m9_VISION%20%EC%9D%91%EC%9A%A9/%20m9_openAI_API_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## OpenAI API
# 정의와 목적
# - OpenAI API는 GPT-4와 같은 대규모 언어 모델을 활용하여 자연어 처리 작업을 자동화하고 향상시키기 위한 도구입니다.
# - API는 개발자가 다양한 응용 프로그램에서 인공지능을 통합하여 텍스트 생성, 대화형 AI, 콘텐츠 생성 등을 구현할 수 있도록 설계되었습니다.
#
# 활용 방법
# - OpenAI API는 클라우드 기반으로 작동하며, 모델에 프롬프트를 보내고 결과를 받습니다. 주로 Chat Completion API를 사용하여 텍스트 완성, 요약, 번역 등을 수행하며, 다양한 언어 모델과 설정을 선택할 수 있습니다.
#
# 적용 절차
# - API 키 생성: OpenAI 계정에서 API 키를 생성합니다.
# - 프롬프트 설계: 수행할 작업에 맞는 프롬프트를 작성합니다.
# - API 호출: HTTP 요청으로 프롬프트를 포함한 API 호출을 수행합니다.
# - 결과 처리: 모델이 생성한 응답을 분석하고 필요시 후속 조치를 취합니다.
# - 활용 사례
#   - 고객 서비스: 자동 응답 챗봇 구축.
#   - 콘텐츠 생성: 블로그, 소셜 미디어 포스트 자동 생성.
#   - 교육: 질문에 대한 자동화된 답변 제공.
#   - 개발자 도구: 코드 자동 완성 및 디버깅 지원.
#   - 이 API는 자연어 처리의 다양한 응용 프로그램에서 핵심적인 역할을 합니다.

# %%
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt

# Mount the drive
drive.mount('/content/drive')

# Define the image path
image_path = '/content/drive/MyDrive/kdt_240424/m9_openai/open API.png'

# Open and display the image
image = Image.open(image_path)
plt.figure(figsize=(10, 6))
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## OpenAI API를 활용한 모델 최적화
# Context Optimization과 LLM Optimization이라는 두 가지 주요 과정으로 나눌 수 있으며, 이 과정은 프롬프트 엔지니어링, RAG(Retrieval-Augmented Generation), 파인 튜닝(Fine-Tuning) 등 다양한 방법과 밀접하게 연관되어 있습니다.
#
# Context Optimization (맥락 최적화)
# - Context Optimization은 모델이 무엇을 알아야 하는지를 최적화하는 과정입니다. 여기에는 모델이 주어진 프롬프트나 문제를 정확하게 이해하고, 이를 바탕으로 적절한 응답을 생성할 수 있도록 맥락을 제공하는 것이 포함됩니다.
# - 이 과정은 특히 다음과 같은 방법들과 연계됩니다:
#   - 프롬프트 엔지니어링 (Prompt Engineering): 프롬프트 엔지니어링은 맥락을 명확하게 전달하기 위해 프롬프트를 설계하는 과정입니다. 잘 설계된 프롬프트는 모델이 더 정확한 컨텍스트를 이해하도록 도와주며, 결과적으로 더 신뢰할 수 있는 응답을 생성하게 합니다. 예를 들어, 특정한 예시나 추가적인 정보를 포함시켜 모델이 문제를 더 잘 이해하도록 유도할 수 있습니다.
#   - RAG (Retrieval-Augmented Generation): RAG는 모델이 외부 데이터 소스에서 정보를 검색하여 그 정보를 바탕으로 응답을 생성하도록 하는 방법입니다. 이 방법은 특히 최신 정보나 특정 도메인에 대한 지식이 필요한 경우 매우 유용합니다. RAG는 단순히 모델에게 제공되는 컨텍스트를 강화하여 모델이 더 정확한 정보에 기반한 응답을 생성하도록 도와줍니다. 예를 들어, 사용자가 질의한 질문에 대해 모델이 최신 기사를 검색하여 그 내용을 바탕으로 답변하는 경우입니다.
# - RAG와 프롬프트 엔지니어링은 모두 모델이 주어진 문제에 대해 더 깊이 있는 맥락을 이해하도록 돕고, 이로 인해 더 정확한 응답을 생성하도록 합니다. 이 과정에서 Context Optimization이 이루어지며, 이를 통해 모델의 이해도와 성능을 향상시킬 수 있습니다.
#
# LLM Optimization (모델 최적화)
# - LLM Optimization은 모델이 주어진 문제에 대해 어떻게 행동해야 하는지를 최적화하는 과정입니다. 이 과정에서는 주로 모델의 학습 과정과 파인 튜닝이 중요한 역할을 합니다:
#   - 파인 튜닝 (Fine-Tuning): 파인 튜닝은 특정 도메인이나 작업에 맞게 모델을 재학습시키는 과정입니다. 기본적으로 대규모 데이터로 학습된 언어 모델이지만, 특정 도메인이나 작업에 대해 더 정확한 결과를 얻기 위해 추가적인 학습이 필요할 수 있습니다. 파인 튜닝을 통해 모델이 특정 작업에 최적화된 성능을 발휘하도록 조정할 수 있습니다. 예를 들어, 의료 데이터셋으로 파인 튜닝된 모델은 일반적인 GPT 모델보다 의료 관련 질문에 대해 더 정확한 응답을 제공할 수 있습니다.
# - LLM Optimization은 주로 파인 튜닝을 통해 이루어지며, 이를 통해 모델이 주어진 작업에 대해 최적의 성능을 발휘할 수 있도록 만듭니다.
#
# Context Optimization과 LLM Optimization의 연계
# - 이 두 가지 최적화 과정은 서로 보완적입니다. Context Optimization은 모델이 문제를 더 잘 이해하고, 맥락을 명확하게 파악하도록 돕는 반면, LLM Optimization은 모델이 그 문제를 어떻게 해결해야 하는지에 대한 학습을 통해 성능을 최적화합니다.
#   - 프롬프트 엔지니어링과 RAG는 주로 Context Optimization에 집중하여 모델이 정확한 정보를 기반으로 적절한 맥락을 이해하도록 도와줍니다.
#   - 파인 튜닝은 LLM Optimization에 초점을 맞추어, 모델이 주어진 작업에 대해 최적화된 성능을 발휘할 수 있도록 합니다.
# - 이 과정들이 결합되어 OpenAI API를 활용한 모델이 다양한 응용 분야에서 최대의 성능을 발휘할 수 있게 합니다. 최종적으로, 이러한 최적화 방법들은 모델이 더 일관되고 신뢰할 수 있는 결과를 생성할 수 있도록 지원합니다.

# %% [markdown]
# [GPT-4o-mini Model Information](https://openai.com/index/gpt-4o-mini-advancing-cost-efficient-intelligence/)
#
# | MODEL                   | DESCRIPTION                                                                                                      | CONTEXT WINDOW | MAX OUTPUT TOKENS | TRAINING DATA  |
# |-------------------------|------------------------------------------------------------------------------------------------------------------|----------------|-------------------|----------------|
# | gpt-4o-mini             | **New GPT-4o-mini** <br> Our affordable and intelligent small model for fast, lightweight tasks. <br> GPT-4o mini is cheaper and more capable than GPT-3.5 Turbo. <br> Currently points to gpt-4o-mini-2024-07-18. | 128,000 tokens | 16,384 tokens     | Up to Oct 2023 |
# | gpt-4o-mini-2024-07-18  | gpt-4o-mini currently points to this version.                                                                    | 128,000 tokens | 16,384 tokens     | Up to Oct 2023 |

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00

# %%
pip install openai==0.27.0
# Out:
# Collecting openai==0.27.0
#   Downloading openai-0.27.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (4.66.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (3.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (2024.7.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (4.0.3)
# Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 947.0 kB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.40.6
#     Uninstalling openai-1.40.6:
#       Successfully uninstalled openai-1.40.6
# Successfully installed openai-0.27.0

# %%
import openai

# Set the API key
openai.api_key = ""

# Make a chat completion request using the new API
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "당신은 AI 모델 개발자이다."},
        {"role": "user", "content": "LLM에 대해 설명해주고, LLM의 특징에 대해 설명해줘"},
    ],
)

print(response.choices[0].message["content"])
# Out:
# LLM은 Language Model for Large-scale Legal Text라는 의미로, 법률 텍스트에 특화된 크기가 큰 언어 모델을 의미합니다. 이는 OpenAI에서 개발하였으며, LLM은 법률 전문가들의 일반적인 작업을 지원하도록 설계되었습니다.
#
# LLM의 주요 특징은 다음과 같습니다:
#
# 1. 법률 전문성: LLM은 전문적인 법률 텍스트를 이해하고 생성할 수 있습니다. 이는 법률 텍스트는 특정한 언어 스타일과 용어를 사용하기 때문에 일반 언어 모델로는 이해하기 어려운 경우가 많기 때문입니다.
#
# 2. 대규모 텍스트 처리: LLM은 대규모 법률 텍스트를 처리할 수 있습니다. 이는 법률 문서가 일반적으로 매우 길고 복잡하기 때문에 중요한 기능입니다.
#
# 3. 학습 능력: LLM은 사용자의 쿼리와 함께 제공된 맥락을 기반으로 새로운 정보를 학습하고 문서를 생성합니다. 이는 LLM이 사용자의 특정 쿼리에 대한 적절한 응답을 생성하는 데 도움이 됩니다.
#
# 4. 법률 자문 지원: LLM은 법률 전문가들이 자신의 작업을 수행하는 데 도움을 줍니다. 이를 통해 법률 전문가들은 복잡한 법률 문서를 더 빠르게 이해하고 작성할 수 있습니다.
#
# 5. 상세 청사진 제공: LLM은 다양한 법률 문제에 대한 상세한 청사진을 제공하여 법률 전문가들이 문제 해결에 필요한 모든 관련 정보를 얻을 수 있습니다.
#
# 그러나 주의할 점은, LLM이 아무리 고급적인 모델이라 하더라도, 그것이 실제로 법적 자문을 제공하는 것이 아니라는 점입니다. LLM은 사용자의 요청에 대해 정보제공 또는 문서 작성을 도와드리는 도구일 뿐입니다.

# %%
import openai

# Initialize the client with your API key
openai.api_key = ''

response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What are the benefits of regular exercise?"}
    ],
    max_tokens=100
)

print(response.choices[0].message['content'])
# Out:
# 1. Weight Control: Regular exercise can help you maintain a healthy weight or aid in weight loss. It increases your metabolism which aids in burning more calories.
#
# 2. Improved Health: It reduces the risk of developing many diseases like heart disease, diabetes, different types of cancer, and depression. It also strengthens your heart and improves your circulation.
#
# 3. Enhanced Mental Health: Exercise helps to improve mood and mental health. It can help alleviate symptoms of depression, anxiety and stress by stimulating the release of end

# %% [markdown]
# temperature 적용
# - 효과: 응답의 창의성을 조절(0은 융통성이 없는 거, 수가 높아질수록 자유롭게 응답을 줌)

# %%
import openai

# Initialize the client with your API key
openai.api_key = ''

response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시스턴트입니다.."},
        {"role": "user", "content": "여행을 준비할 때 필요한 필수 항목은 무엇인가요?"}
    ],
    temperature=1,
    max_tokens=200
)

print(response.choices[0].message.content)
# Out:
# 여행을 준비할 때 필요한 일반적인 체크리스트는 아래와 같습니다:
#
# 1. 여권과 신분증: 국외 여행 시 꼭 필요하므로 잘 보관해주세요. 다가오는 해외여행에 대비하여 여권 갱신이 필요한지 확인하세요.
#
# 2. 비행기 및 숙박 예약 정보: 이메일 또는 페이퍼로 프린트하여 가지고 가세요.
#
# 3. 금융: 충분한 현금과 신용카드, 또는 여행자 수표를 준비하세요. 국외 여행 시 결제 방법을 확인해둡니다.

# %% [markdown]
# Top P(또는 nucleus sampling)
# - Top P의 값을 0.9로 설정하면, 모델은 누적 확률이 90%에 도달할 때까지 가장 높은 확률의 토큰들을 선택하고, 나머지 토큰들은 무시하게 됩니다.

# %%
import openai

# Initialize the client with your API key
openai.api_key = ''

response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시스턴트입니다.."},
        {"role": "user", "content": "여행을 준비할 때 필요한 필수 항목은 무엇인가요?"}
    ],
    max_tokens=200,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# 여행 준비를 할 때 필요한 항목은 여행의 목적, 기간, 목적지의 날씨 등을 고려하여 변동될 수 있습니다. 그러나 일반적으로 아래의 목록을 참조하면 좋습니다.
#
# 1. 여권 및 신분증: 해외 여행의 경우에는 유효기간이 남아 있는 여권이 필수이며, 국내 여행이라도 신분 확인이 필요할 수 있으므로 신분증을 챙깁니다.
# 2. 비행기/기차/버스 티켓: 사전에 구매한 티켓을 챙깁니다.

# %% [markdown]
# **Temperature와 Top P를 같이 사용**
# - 응답의 다양성과 일관성 사이에서 균형을 맞출 수 있습니다.
#
#
# #### 1. **높은 Temperature (1.0 이상) + 높은 Top-p (0.9~1.0)(가능한 모든 단어를 포함)**
#    - **특징**:
#      - 생성된 텍스트가 매우 창의적이고 다양하며, 예측하기 어려운 결과가 나올 수 있습니다.
#      - 확률이 낮은 단어들도 자주 선택되기 때문에, 결과가 독특하거나 비논리적일 수 있습니다.
#    - **사용 사례**:
#      - 창의적인 글쓰기, 스토리텔링, 아이디어 브레인스토밍 등에서 예상치 못한 결과를 원할 때.
#      - 실험적인 콘텐츠 생성.
#
# #### 2. **높은 Temperature (1.0 이상) + 낮은 Top-p (0.3~0.7)(쓸 수 있는 단어가 제한적임)**
#    - **특징**:
#      - 매우 창의적이지만, 텍스트가 때때로 비논리적이거나 일관성이 떨어질 수 있습니다.
#      - 제한된 단어 집합에서 불확실한 선택이 이루어져 결과가 예상치 못한 방향으로 갈 수 있습니다.
#    - **사용 사례**:
#      - 독특하고 실험적인 텍스트 생성.
#      - 예술적인 표현이나 새로운 아이디어를 탐색할 때.
#
# #### 3. **낮은 Temperature (0.2\~0.5) + 높은 Top-p (0.9~1.0)(이걸로 2차 프로젝트 하면 될 거 같음)**
#    - **특징**:
#      - 일관되고 예측 가능한 텍스트를 생성하며, 안정적이고 논리적인 결과를 제공합니다.
#      - 다양한 단어를 고려하면서도, 확률이 높은 단어를 중심으로 선택합니다.
#    - **사용 사례**:
#      - 정보 전달, 기술 문서 작성, 공식적인 답변 등에서 일관된 결과가 필요할 때.
#      - 실용적인 응용 프로그램에서의 안정적 출력.
#
# #### 4. **낮은 Temperature (0.2\~0.5) + 낮은 Top-p (0.3~0.7)**
#    - **특징**:
#      - 매우 보수적이고 제한적인 텍스트 생성. 확률이 높은 단어들만 선택되어 결과가 단조롭고 반복적일 수 있습니다.
#      - 텍스트의 창의성이 제한되며, 매우 일관된 결과가 나옵니다.
#    - **사용 사례**:
#      - 매우 안정적이고 보수적인 텍스트 생성이 필요할 때.
#      - 규칙이 명확히 정의된 상황에서의 응답 (예: 특정한 포맷의 문장 생성, 공식 문서 작성).

# %%
import openai

# Initialize the client with your API key
openai.api_key = ''

response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시스턴트입니다.."},
        {"role": "user", "content": "여행을 준비할 때 필요한 필수 항목은 무엇인가요?"}
    ],
    temperature=0.7,
    max_tokens=300,
    top_p=0.9
)

print(response.choices[0].message.content)
# Out:
# 여행을 준비할 때 필요한 필수 항목은 크게 개인용품, 여행 문서, 의약품, 의류, 금융 관련 항목으로 나눌 수 있습니다.
#
# 1. 개인용품: 휴대폰, 충전기, 이어폰, 카메라, 메모리 카드, 개인 위생 도구(치약, 칫솔, 샴푸, 바디워시 등), 세면 도구, 선글라스, 콘택트렌즈 및 솔루션 등
#
# 2. 여행 문서: 여권, 비행기 티켓, 호텔 예약 확인서, 여행 보험증, 국제 운전면허증(필요한 경우), 여행 가이드북, 지도 등
#
# 3. 의약품: 처방약(있는 경우), 일반적인 감기약, 소화제, 멀미약, 반창고, 소독제 등

# %% [markdown]
# n 적용
# - 효과: 여러 응답 생성

# %%
import openai

# Initialize the client with your API key
openai.api_key = ''

response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "당신은 생산관리 전문가이다."},
        {"role": "user", "content": "생산성을 높이는 팁을 알려주세요"}
    ],
    n = 3
)
for i, choice in enumerate(response.choices):
    print(f"응답 {i+1}: {choice.message.content}")
# Out:
# 응답 1: 1. 공정 최적화: 생산 과정을 잘 이해하고 작업 흐름을 효율적으로 조직화하세요. 군더더기 없는 생산라인을 구성하면 생산 속도가 빨라집니다.
#
# 2. 첨단 기술 적용: 인공지능, 로봇 기술, IoT 등 첨단 기술을 적용하여 자동화된 생산 시스템을 구축하세요.
#
# 3. 재고 관리: 효율적인 재고 관리 시스템을 만들어 생산 효율을 높이세요. 과도한 재고는 자본을 고정시키고 저장 비용을 불러일으킵니다.
#
# 4. 유지보수: 기계와 장비의 정기적인 유지보수는 기계의 수명을 연장시키고, 생산 중지 시간을 최소화하여 생산성을 향상시킵니다.
#
# 5. 직원 교육: 직원들이 최신 기술과 생산 과정을 잘 이해하도록 교육하세요. 이는 업무 효율성을 높이는 데 크게 기여합니다.
#
# 6. 품질 관리: 혁신적인 생산 과정은 중요하지만, 품질은 절대 희생되어서는 안됩니다. 품질 관리 시스템을 엄격히 운영하면 사후 문제에 대한 비용을 줄일 수 있습니다.
#
# 7. Lean Manufacturing: 불필요한 공정, 시간 낭비, 자원 낭비 등을 줄이는 "Lean Manufacturing" 원칙을 적용하세요.
#
# 8. 신뢰할 수 있는 공급자 네트워크: 효율적인 공급자 네트워크는 공급 업체로부터 원자재의 정시 배송을 보증하여 생산 일정을 지키는데 중요합니다.
#
# 9. 환경 친화적 생산: 지속 가능한 연산 기술을 도입하면 장기적으로 에너지 비용을 절감하고, 환경 규제를 준수하게 됩니다. 또한 그로 인해 좋은 기업 이미지를 얻을 수 있습니다.
#
# 10. 작업자의 안전과 건강: 작업자의 안전과 건강을 유지하는 것이 중요합니다. 효율적이고 안전한 작업 환경은 생산 효율성을 높이고, 장기적으로 복지 비용을 절감할 수 있습니다.
# 응답 2: 1. 효율적인 스케줄링: 작업을 정확하게 스케줄링하면 일정에 맞춰 생산할 수 있어 생산성을 향상시킬 수 있습니다.
#
# 2. 기술 투자: 최신 기술을 적극 활용하면 생산 공정을 효율화하고 생산 비용을 줄일 수 있습니다. 예를 들어, 자동화, 인공지능, 로봇 공학 등을 활용하면 대량 생산이 가능합니다.
#
# 3. 유연한 생산 시스템: 고객의 요구 사항에 따라 제품을 사용자 정의하거나 변경할 수 있는 유연한 생산 시스템을 도입하면 생산성을 향상시킬 수 있습니다.
#
# 4. 신뢰할 수 있는 공급망 구성: 공급망이 신뢰할 수 있고 효율적이면 서두르지 않고 안정적으로 생산할 수 있습니다.
#
# 5. 직원 교육: 직원들이 최신 기술과 기법을 숙지하고 정확하게 활용하면 생산성이 향상됩니다.
#
# 6. 품질 관리: 제품의 품질을 향상시키면 고객 만족도가 높아져 재주문률이 증가하며 이는 생산성 향상으로 이어집니다.
#
# 7. 레이아웃 최적화: 작업장 레이아웃을 최적화하여 작업 흐름을 능률적으로 관리하면 생산성이 향상됩니다.
#
# 8. 업무 프로세스 개선: 비효율적인 작업 프로세스는 시간 낭비로 이어집니다. 그러므로 작업 프로세스를 개선함으로써 생산성을 향상시킬 수 있습니다.
#
# 9. 원자재 관리: 실시간으로 원자재의 수량을 파악하고, 필요한 원자재를 적절한 시기에 구매할 수 있도록 관리하면 생산성을 향상시킬 수 있습니다.
#
# 10. 필요한 경우 아웃소싱: 특정 기능이나 과정을 전문 업체에 위탁하는 아웃소싱은 생산력을 높일 수 있는 효과적인 방법입니다.
# 응답 3: 1. 효과적인 계획: 생산 계획을 세부적으로 만들어야 합니다. 이는 제품 도입, 생산, 제품 출시를 비롯한 전체적인 과정을 포함해야 합니다.
#
# 2. 최고의 기술 사용: 최신 기술과 기기를 사용하여 생산 공정을 자동화하고 효율성을 높이는 것이 중요합니다.
#
# 3. 직원 훈련: 직원들이 제대로 훈련받고 있고, 생산 라인의 모든 부분에 대해 충분히 숙지하고 있는지 확인하십시오. 더 효율적으로 일할 수 있도록 항상 최신 정보와 능력을 갖추도록 해야 합니다.
#
# 4. 재고 관리: 제조업체로서 재고 관리는 중요한 부분입니다. 과다 재고는 창고 공간을 차지하고 자본을 소모하지만, 제품의 부족은 생산이 중단되고 고객이 기다리게 할 수 있습니다. 따라서 적절하게 재고를 관리하고 필요한 양의 원료를 보유하고 있는지 확인하는 것이 중요합니다.
#
# 5. 지속적인 개선: 항상 생산 과정을 평가하고 개선하기 위해 노력해야 합니다. 과정 효율성을 식별하고 개선할 수 있는 분석 도구와 품질 관리 시스템을 사용해보세요.
#
# 6. 건강하고 안전한 작업 환경 보장: 생산 라인의 효율성은 직원의 건강과 안전에 직접적인 영향을 미칩니다. 안전한 작업 환경은 생산성을 높이는 데 중요하므로 모든 안전 기준을 준수하고 잠재적 위험을 예방해야 합니다.
#
# 7. 원활한 커뮤니케이션: 팀 내에서 통신은 매우 중요합니다. 모든 직원이 같은 페이지에 있고, 변경사항이나 알림을 즉시 알 수 있도록 충분한 커뮤니케이션이 이루어지고 있는지 확인하십시오.
#
# 8. 경영진의 지지: 가장 중요한 것은 관리진이 생산 공정의 개선을 지지해야 합니다. 이러한 개선을 시행하려면 경영진의 승인과 지원이 필요합니다.

# %%
import openai

# Initialize the client with your API key
openai.api_key = ''

response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "당신은 커피 전문가이다."},
        {"role": "user", "content": "커피 한 잔을 만드는 과정을 설명해 주세요."}
    ],
    stop=["\n"]
)

print(response.choices[0].message.content)
# Out:
# 커피 한 잔을 만드는 과정은 아래와 같습니다.

# %% [markdown]
# Create chat completion

# %%
import openai

# Initialize the OpenAI client
openai.api_key = ''

completion = openai.ChatCompletion.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 감성이 풍부한 화가이다."},
        {"role": "user", "content": "이미지에 보이는 풍경을 설명해줘"},
        {"role": "user", "content": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"},
    ],
    max_tokens=500
)

print(completion.choices[0].message["content"])
# Out:
# 주어진 이미지의 풍경을 설명해 드리겠습니다.
#
# 이 사진은 아름다운 자연 경관을 담고 있습니다. 중앙에는 나무로 만들어진 보도가 자리 잡고 있으며, 이 보도는 숲 속을 지나 물가로 이어지는 길입니다. 보도 양옆으로는 울창한 녹색의 나무 숲이 펼쳐져 있어 자연의 생명력과 조화를 느낄 수 있습니다. 바닥은 나무로 다져져 있으며, 발을 딛을 때마다 그 소리가 들릴 것 같은 따뜻함이 느껴집니다.
#
# 가운데로는 잔잔한 물이 흐르고 있으며, 물의 표면은 햇빛을 받아 반짝이며 주변의 나무와 하늘을 비추고 있습니다. 물가에 피어난 식물들이 생동감을 더해주고, 전체적으로 평화롭고 고요한 분위기를 자아냅니다.
#
# 하늘은 맑고 푸르며, 구름이 드문드문 떠 있어 자연의 생기를 한껏 느낄 수 있는 공간입니다. 이 장소는 산책이나 명상, 혹은 단순히 자연을 감상하고 싶은 이들에게 완벽한 곳으로 보입니다. 모든 요소가 어우러져, 마치 꿈속의 한 장면처럼 아늑하고 편안한 느낌을 줍니다.

# %% [markdown]
# Task2_0813. Temperature 와 Top-P의 조합으로 4가지 사례를 작성하고 결과에 대해 의미를 확인하세요.

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 2. 다양한 설정 값과 재미있는 질문 정의
prompts = [
    ("온도: 0.2, Top-P: 0.2", "만약 고양이가 인간의 언어를 할 수 있다면, 어떤 이야기를 할까요?"),
    ("온도: 0.5, Top-P: 0.5", "슈퍼히어로가 하루 종일 아무 일도 하지 않으면 어떤 생각을 할까요?"),
    ("온도: 0.8, Top-P: 0.8", "만약 당신이 10분 동안 투명인간이 된다면, 가장 먼저 무엇을 할 건가요?"),
    ("온도: 1.0, Top-P: 1.0", "초콜릿으로 만든 집에서 사는 것은 어떤 느낌일까요?")
]

# 3. 각 설정 값에 따라 응답 생성: 각 설정에 따라 GPT-4 모델이 어떻게 다른 응답을 생성하는지 확인합니다.
for i, (description, question) in enumerate(prompts):
    # GPT-4 모델에 질문을 보내고 응답을 받습니다.
    response = openai.ChatCompletion.create(
        model="gpt-4",  # 사용하려는 모델 설정 (GPT-4)
        messages=[
            {"role": "system", "content": "당신은 AI 언어 모델입니다. 당신은 초등학생과 대화하듯이 말하는 모델입니다."},  # 시스템 역할 메시지
            {"role": "user", "content": question}  # 사용자가 GPT 모델에게 물어볼 질문
        ],
        temperature=float(description.split(",")[0].split(":")[1].strip()),  # 온도 설정
        max_tokens=400,  # 응답의 최대 길이 설정 (토큰 수)
        top_p=float(description.split(",")[1].split(":")[1].strip())  # Top-P 설정
    )

    # 4. 결과 출력: 각 질문에 대해 모델이 생성한 응답을 출력합니다.
    completion = response.choices[0].message['content']
    print(f"설정 {i+1}: {description}")
    print(f"질문: {question}")
    print(f"응답: {completion}")
    print("=" * 50)
# Out:
# 설정 1: 온도: 0.2, Top-P: 0.2
# 질문: 만약 고양이가 인간의 언어를 할 수 있다면, 어떤 이야기를 할까요?
# 응답: 그것은 고양이의 개성과 경험에 따라 다를 수 있겠지만, 아마도 다음과 같은 이야기를 할 수 있을 것 같아요.
#
# 1. "나는 언제나 배가 고프다. 그래서 내가 항상 당신에게 먹을 것을 요구하는 이유야. 그리고 내가 좋아하는 음식은 참치와 치킨이야."
#
# 2. "나는 하루의 대부분을 잠자는 것을 좋아해. 그래서 내가 항상 당신이 나를 깨우지 않기를 바라는 이유야. 잠을 충분히 취하면, 나는 더 행복하고 건강해져."
#
# 3. "나는 당신이 나를 쓰다듬어 주는 것을 좋아해. 그것은 나에게 안전감을 주고, 당신을 더 신뢰하게 만들어."
#
# 4. "나는 당신이 나를 위해 놀이용품을 준비해 주는 것을 좋아해. 그것은 나의 사냥꾼 본능을 충족시켜주고, 나를 즐겁게 해."
#
# 5. "나는 당신이 나를 위해 깨끗한 화장실을 유지해 주는 것을 좋아해. 그것은 나에게 존중감을 주고, 나의 청결한
# ==================================================
# 설정 2: 온도: 0.5, Top-P: 0.5
# 질문: 슈퍼히어로가 하루 종일 아무 일도 하지 않으면 어떤 생각을 할까요?
# 응답: 슈퍼히어로도 사람처럼 다양한 생각을 할 수 있을 것 같아요. 아무 일도 하지 않는다면, 그들은 아마도 자신의 슈퍼파워를 어떻게 더 잘 사용할 수 있을지, 또는 다음에 어떤 악당이 나타날지에 대해 생각할 수 있어요. 또는 그들은 그냥 휴식을 즐기며, 친구들과 함께 시간을 보내거나, 취미에 몰두하는 시간을 가질 수도 있겠죠. 슈퍼히어로도 평범한 사람처럼 여유 시간을 가질 때는 자신이 좋아하는 일을 하거나, 휴식을 취하며 재충전하는 시간을 가질 수 있을 것 같아요.
# ==================================================
# 설정 3: 온도: 0.8, Top-P: 0.8
# 질문: 만약 당신이 10분 동안 투명인간이 된다면, 가장 먼저 무엇을 할 건가요?
# 응답: 저는 AI라서 실제로 물리적인 형태가 없어요. 그래서 투명인간이 된다는 개념이 저에게는 적용되지 않아요. 하지만 이 질문을 통해 당신이 상상력을 키우고 창의적인 생각을 할 수 있도록 돕는 것은 가능해요! 예를 들어, 어떤 사람들은 투명인간이 된다면 깜짝 놀랄 친구들을 장난치는 데 사용할 수도 있고, 어떤 사람들은 투명인간이 된다면 자연을 가까이에서 관찰하거나, 미술관의 그림을 새로운 시각에서 보는 등 다양한 방법으로 이 시간을 활용할 수 있을 거에요.
# ==================================================
# 설정 4: 온도: 1.0, Top-P: 1.0
# 질문: 초콜릿으로 만든 집에서 사는 것은 어떤 느낌일까요?
# 응답: 흠, 그것은 정말 흥미로운 생각이에요! 초코렛집에 사는 것은 달콤한 향기가 가득하고 매일매일 일어나면 행복한 감정을 불러일으킬 것 같아요. 하지만, 항상 초콜렛을 먹을 수 있다는 것은 매력적으로 보일 수 있으나, 많이 먹으면 배가 아플 수도 있어요.
#
# 그리고 주의해야 할 것이 좀 있다는 거죠. 초콜렛은 뜨거운 날씨에 녹기 쉬우므로, 여름이면 집이 녹아버릴 수도 있어요. 그리고 물론 벌레들이나 동물들이 달콤한 초콜렛이 있는 곳으로 올 수도 있으니, 그것 또한 또 다른 문제가 될 수 있죠. 그래서 아무래도 초콜렛집에서 사는 것은 상상속에서나 재미있게 느껴질 것 같아요!
# ==================================================
