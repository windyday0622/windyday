# %% [markdown]
# <a href="https://colab.research.google.com/github/windyday0622/windyday/blob/main/m8_%EC%9E%90%EC%97%B0%EC%96%B4%EC%B2%98%EB%A6%AC%20%EC%B1%97%EB%B4%87%20%EA%B0%9C%EB%B0%9C%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/%202%EC%B0%A8_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2024/08/13

# %%
# %pip install -q openai

# %%
pip install openai==0.28.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.42.0
#     Uninstalling openai-1.42.0:
#       Successfully uninstalled openai-1.42.0
# ...

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간 등 입니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 찾은 상품을 *상품을 추천해주는 형태* 와 같이 응답합니다.

  *상품을 추천해주는 형태*
  - 우대 조건이 있는 상품 중에 최고 우대 금리가 가장 높은 상품 상위 3개를 추천합니다.
  - 우대 조건이 있는 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    '우대 조건'
    의 형태로 답변합니다.
  - 동시에 우대 조건이 없는 상품 중에 세후 이자율이 가장 높은 상품 상위 3개를 추천합니다.
  - 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    의 형태로 답변합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 :

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "나는 27살 남자이고, 매달 10만원 씩 적금을 12개월동안 할 거 같은데 나한테 추천해줄만한 적금 상품이 있을까 ?"

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력
print("추천 상품 목록:")
print(response['choices'][0]['message']['content'])
# Out:
# 추천 상품 목록:
# 네, 고객님의 상황에 맞는 적금 상품을 찾아보았습니다.
#
# 우대 조건이 있는 상품 중에서는 다음과 같은 상품들을 추천드립니다.
#
# 1. '청년적금 - 신한은행'
#    금리: 연 2.0%
#    가입대상: 20~29세 청년
#    상품 안내: 청년들을 위한 특별한 적금 상품입니다.
#    우대 조건: 신한통장으로 급여를 입금받는 경우 연 0.2%p 추가 우대
#
# 2. '희망적금 - NH농협은행'
#    금리: 연 2.1%
#    가입대상: 20~34세 청년
#    상품 안내: 청년들의 첫 적금 가입을 응원하는 상품입니다.
#    우대 조건: NH농협은행의 희망통장을 사용하는 경우 연 0.1%p 추가 우대
#
# 3. '청춘적금 - KB국민은행'
#    금리: 연 2.2%
#    가입대상: 20~29세 청년
#    상품 안내: 청춘들을 위한 특별한 적금 상품입니다.
#    우대 조건: KB국민은행의 청춘통장을 사용하는 경우 연 0.2%p 추가 우대
#
# 우대 조건이 없는 상품 중에서는 다음과 같은 상품들을 추천드립니다.
#
# 1. '스마트적금 - SC제일은행'
#    금리: 연 1.8%
#    가입대상: 누구나
#    상품 안내: 스마트한 선택, SC제일은행의 스마트적금입니다.
#
# 2. 'i-적금 - 하나은행'
#    금리: 연 1.7%
#    가입대상: 누구나
#    상품 안내: 언제나, 어디서나 쉽고 편리하게 가입할 수 있는 i-적금입니다.
#
# 3. '프리미엄적금 - KDB산업은행'
#    금리: 연 1.6%
#    가입대상: 누구나
#    상품 안내: 고객님의 자산을 안전하게 운용할 수 있는 프리미엄적금입니다.
#
# 이 중에서 고객님의 상황에 가장 적합한 상품을 선택하시면 됩니다. 궁금한 점이 있으시면 언제든지 물어보세요.

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간 등 입니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 찾은 상품을 *상품을 추천해주는 형태* 와 같이 응답합니다.
  4. 우대 조건이 있는 상품의 경우, 우대 조건들을 고객에게 알려주고, 고객이 선택한 조건에 따라 최대로 받을 수 있는 우대 금리를 계산합니다.
  5. 최종적으로 기본 금리 상품 상위 3개와 우대 조건을 고려한 상품 상위 3개를 추천합니다.

  *상품을 추천해주는 형태*
  - 우대 조건이 있는 상품 중에 최고 우대 금리가 가장 높은 상품 상위 3개를 추천합니다.
  - 우대 조건이 있는 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    '우대 조건'
    의 형태로 답변합니다.
  - 동시에 우대 조건이 없는 상품 중에 세후 이자율이 가장 높은 상품 상위 3개를 추천합니다.
  - 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    의 형태로 답변합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 :

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "나는 27살 남자이고, 매달 10만원 씩 적금을 12개월동안 할 거 같은데 나한테 추천해줄만한 적금 상품이 있을까?"

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력
print("우대 조건에 따른 최대 우대 금리 계산 및 추천 상품 목록:")

# 우대 조건을 고객에게 제시하고 선택받기
response_text = response['choices'][0]['message']['content']
print(response_text)

# 여기서 우대 조건을 추출하고, 사용자가 선택할 수 있게 한다고 가정
# (사용자가 선택한 조건을 기반으로 계산 수행)
user_selected_conditions = ["자동이체", "급여 이체"]  # 예시: 사용자가 선택한 우대 조건

# 우대 조건에 따른 금리 계산 (예시 계산)
max_bonus_rate = 0.5  # 우대 조건을 모두 만족했을 때 최대 우대 금리
user_bonus_rate = 0.0  # 사용자가 선택한 조건에 따른 우대 금리
for condition in user_selected_conditions:
    if condition == "자동이체":
        user_bonus_rate += 0.2
    elif condition == "급여 이체":
        user_bonus_rate += 0.3

# 최종 추천 상품 목록 (우대 조건 포함)
print(f"\n최대 우대 금리: {user_bonus_rate:.2f}%")

# Chat API를 다시 호출하여 최종 추천 상품 목록을 가져오기
final_prompt = f"""
우대 조건을 고려하여 다음의 우대 조건을 충족한 경우를 포함해 최종적으로 추천하는 상품 3개를 추천해주세요:
1. 기본 금리 상품 상위 3개
2. 우대 조건을 충족한 경우의 상위 3개 상품 (충족한 우대 조건: {user_selected_conditions})
"""

final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 최종 추천 상품 출력
print("최종 추천 상품 목록:")
print(final_response['choices'][0]['message']['content'])
# Out:
# 우대 조건에 따른 최대 우대 금리 계산 및 추천 상품 목록:
# 네, 고객님의 요청에 따라 적금 상품을 찾아보았습니다. 매달 10만원씩, 총 12개월 동안 적립하실 예정이시군요.
#
# 우선, 우대 조건이 있는 상품 중에서는 다음과 같은 상품들을 추천드립니다.
#
# 1. '청춘적금 - KB국민은행'
#    - 금리: 1.80%
#    - 가입대상: 14세 ~ 34세 청년 고객
#    - 상품 안내: 매달 일정 금액을 저축해 나가는 적금 상품입니다.
#    - 우대 조건: KB Star Banking 이용 고객, 청년내일채움공제 가입 고객에게 우대 금리를 제공합니다.
#
# 2. '올댓적금 - 신한은행'
#    - 금리: 1.75%
#    - 가입대상: 전 연령 고객
#    - 상품 안내: 매달 일정 금액을 저축해 나가는 적금 상품입니다.
#    - 우대 조건: 신한 FAN 고객, 급여이체 고객에게 우대 금리를 제공합니다.
#
# 3. '내맘대로적금 - 하나은행'
#    - 금리: 1.70%
#    - 가입대상: 전 연령 고객
#    - 상품 안내: 매달 일정 금액을 저축해 나가는 적금 상품입니다.
#    - 우대 조건: 하나멤버스 회원, 급여이체 고객에게 우대 금리를 제공합니다.
#
# 그리고 우대 조건이 없는 상품 중에서는 다음과 같은 상품들을 추천드립니다.
#
# 1. '정기적금 - NH농협은행'
#    - 금리: 1.60%
#    - 가입대상: 전 연령 고객
#    - 상품 안내: 매달 일정 금액을 저축해 나가는 적금 상품입니다.
#
# 2. 'e-적금 - SC제일은행'
#    - 금리: 1.55%
#    - 가입대상: 전 연령 고객
#    - 상품 안내: 인터넷 뱅킹을 통해 가입하고 관리하는 적금 상품입니다.
#
# 3. '스마트적금 - 우리은행'
#    - 금리: 1.50%
#    - 가입대상: 전 연령 고객
#    - 상품 안내: 스마트폰 뱅킹을 통해 가입하고 관리하는 적금 상품입니다.
#
# ...

# %%
# 우대 조건 제공(우대 조건을 기반으로 사용자가 선택할 수 있도록 제공)
# 우대 금리 계산(사용자가 선택한 우대 조건에 따라 각 상품별 최종 금리를 계산)
# 최종 추천 상품 제공(최종적으로 우대 금리를 반영한 추천 상품 상위 3개를 출력하고, ChatGPT API를 통해 추가 정보(기본 금리 상위 3개)를 제공)

import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간 등 입니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 찾은 상품을 *상품을 추천해주는 형태* 와 같이 응답합니다.
  4. 우대 조건이 있는 상품의 경우, 우대 조건들을 고객에게 알려주고, 고객이 선택한 조건에 따라 최대로 받을 수 있는 우대 금리를 계산합니다.
  5. 최종적으로 기본 금리 상품 상위 3개와 우대 조건을 고려한 상품 상위 3개를 추천합니다.

  *상품을 추천해주는 형태*
  - 우대 조건이 있는 상품 중에 최고 우대 금리가 가장 높은 상품 상위 3개를 추천합니다.
  - 우대 조건이 있는 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    '우대 조건'
    의 형태로 답변합니다.
  - 동시에 우대 조건이 없는 상품 중에 세후 이자율이 가장 높은 상품 상위 3개를 추천합니다.
  - 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    의 형태로 답변합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 :

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "나는 20살 여자고, 매달 20만원 씩 적금을 12개월동안 할 거 같은데 나한테 추천해줄만한 적금 상품이 있을까?"

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력
print("우대 조건에 따른 최대 우대 금리 계산 및 추천 상품 목록:")

# 우대 조건을 고객에게 제시하고 선택받기
response_text = response['choices'][0]['message']['content']
print(response_text)

# 예를 들어 챗봇이 제공한 우대 조건 목록이 있다고 가정합시다.
# 예시 우대 조건 목록
bonus_conditions = {
    "1": {"조건": "자동이체", "우대 금리": 0.2},
    "2": {"조건": "급여 이체", "우대 금리": 0.3},
    "3": {"조건": "카드 사용 실적", "우대 금리": 0.1},
}

# 사용자가 선택한 우대 조건을 입력받습니다 (여기서는 예시로 사용자가 1번과 2번 조건을 선택했다고 가정)
user_selected_conditions = ["1", "2"]

# 우대 조건에 따른 금리 계산
user_bonus_rate = sum(bonus_conditions[cond]["우대 금리"] for cond in user_selected_conditions)

# 최종 추천 상품 목록 (우대 조건 포함)
print(f"\n선택한 조건에 따른 최대 우대 금리: {user_bonus_rate:.2f}%")

# Chat API를 다시 호출하여 최종 추천 상품 목록을 가져오기
final_prompt = f"""
사용자가 선택한 우대 조건을 고려하여 다음의 조건을 충족한 경우를 포함해 최종적으로 추천하는 상품 3개를 추천해주세요:
1. 기본 금리 상품 상위 3개
2. 우대 조건을 충족한 경우의 상위 3개 상품 (충족한 우대 조건: {', '.join([bonus_conditions[cond]['조건'] for cond in user_selected_conditions])})
"""

final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 최종 추천 상품 출력
print("최종 추천 상품 목록:")
print(final_response['choices'][0]['message']['content'])
# Out:
# 우대 조건에 따른 최대 우대 금리 계산 및 추천 상품 목록:
# 고객님의 조건에 맞는 적금 상품을 찾아보겠습니다.
#
# 1. 우대 조건이 있는 상품 추천:
#
# - '청년적금 - KB국민은행'
#   금리: 2.5%
#   가입대상: 만 15세 이상 ~ 만 34세 이하 청년
#   상품 안내: 청년들을 위한 적금 상품으로, 1년간 매달 20만원씩 적립하실 수 있습니다.
#   우대 조건: KB국민은행 체크카드 사용금액에 따라 최대 0.2%p 우대 가능
#
# - '청춘적금 - 신한은행'
#   금리: 2.3%
#   가입대상: 만 14세 이상 ~ 만 34세 이하 청년
#   상품 안내: 청년들을 위한 적금 상품으로, 1년간 매달 20만원씩 적립하실 수 있습니다.
#   우대 조건: 신한카드 사용금액에 따라 최대 0.3%p 우대 가능
#
# - '스마트적금 - 하나은행'
#   금리: 2.2%
#   가입대상: 만 18세 이상 고객
#   상품 안내: 스마트폰을 통해 가입하고 관리할 수 있는 적금 상품입니다.
#   우대 조건: 하나카드 사용금액에 따라 최대 0.2%p 우대 가능
#
# 2. 우대 조건이 없는 상품 추천:
#
# - '정기적금 - SC제일은행'
#   금리: 2.1%
#   가입대상: 만 18세 이상 고객
#   상품 안내: 1년간 매달 20만원씩 적립하실 수 있는 정기적금 상품입니다.
#
# - 'i-적금 - 우리은행'
#   금리: 2.0%
#   가입대상: 만 18세 이상 고객
#   상품 안내: 인터넷뱅킹을 통해 가입하고 관리할 수 있는 적금 상품입니다.
#
# - '스마트적금 - KDB산업은행'
#   금리: 1.9%
#   가입대상: 만 18세 이상 고객
#   상품 안내: 스마트폰을 통해 가입하고 관리할 수 있는 적금 상품입니다.
#
# 이 중에서 가장 적합한 상품을 선택해보시는 것은 어떨까요? 추가적인 질문이 있으시면 언제든지 말씀해주세요.
#
# 선택한 조건에 따른 최대 우대 금리: 0.50%
# 최종 추천 상품 목록:
# ...

# %% [markdown]
# CSV 파일 읽기 기능 추가

# %%
# CSV 파일 읽기
# 우대 조건 제공(CSV에서 읽어온 우대 조건을 기반으로 사용자가 선택할 수 있도록 제공)
# 우대 금리 계산(사용자가 선택한 우대 조건에 따라 각 상품별 최종 금리를 계산)
# 최종 추천 상품 제공(최종적으로 우대 금리를 반영한 추천 상품 상위 3개를 출력하고, ChatGPT API를 통해 추가 정보(기본 금리 상위 3개)를 제공)
import openai
import pandas as pd

# 1. OpenAI API 키 설정
openai.api_key = ''

# 2. CSV 파일 불러오기
file_path = 'interest_rate_data.csv'  # 실제 CSV 파일 경로
data = pd.read_csv(file_path)

# 3. 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간 등 입니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 찾은 상품을 *상품을 추천해주는 형태* 와 같이 응답합니다.
  4. 우대 조건이 있는 상품의 경우, 우대 조건들을 고객에게 알려주고, 고객이 선택한 조건에 따라 최대로 받을 수 있는 우대 금리를 계산합니다.
  5. 최종적으로 기본 금리 상품 상위 3개와 우대 조건을 고려한 상품 상위 3개를 추천합니다.

  *상품을 추천해주는 형태*
  - 우대 조건이 있는 상품 중에 최고 우대 금리가 가장 높은 상품 상위 3개를 추천합니다.
  - 우대 조건이 있는 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    '우대 조건'
    의 형태로 답변합니다.
  - 동시에 우대 조건이 없는 상품 중에 세후 이자율이 가장 높은 상품 상위 3개를 추천합니다.
  - 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    의 형태로 답변합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 :

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 4. 사용자 프롬프트 예시
user_prompt = "나는 20살 여자고, 매달 20만원 씩 적금을 12개월동안 할 거 같은데 나한테 추천해줄만한 적금 상품이 있을까?"

# 5. Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 6. 우대 조건을 고객에게 제시하고 선택받기
response_text = response['choices'][0]['message']['content']
print(response_text)

# 우대 조건을 제공할 때 상품별로 제공
for index, row in data.iterrows():
    print(f"\n상품명: {row['상품명']} - {row['은행명']}")
    print(f"기본 금리: {row['기본 금리']}")
    conditions = []
    for i in range(1, 4):
        if pd.notna(row[f'우대 조건 {i}']):
            conditions.append(f"{i}: {row[f'우대 조건 {i}']} ({row[f'우대 조건 {i} 금리']}%)")
    print("우대 조건:")
    print(", ".join(conditions))

# 7. 사용자가 선택한 우대 조건을 받아 우대 금리 계산
user_selected_conditions = {
    "상품 A": ["1", "2"],  # 예시로 사용자가 선택한 조건
    "상품 B": ["1"]
}

# 8. 각 상품별 최종 금리 계산
final_rates = {}
for index, row in data.iterrows():
    product_name = row['상품명']
    base_rate = float(row['기본 금리'].replace('%', ''))
    bonus_rate = 0.0

    if product_name in user_selected_conditions:
        for condition in user_selected_conditions[product_name]:
            bonus_rate += float(row[f'우대 조건 {condition} 금리'].replace('%', ''))

    final_rates[product_name] = base_rate + bonus_rate

# 9. 최종 추천 상품 목록 (우대 조건 포함)
sorted_products = sorted(final_rates.items(), key=lambda item: item[1], reverse=True)
top_3_products = sorted_products[:3]

print("\n최종 추천 상품 목록 (우대 금리 포함):")
for product, rate in top_3_products:
    print(f"{product}: {rate:.2f}%")

# 10. Chat API를 다시 호출하여 최종 추천 상품 목록을 가져오기
final_prompt = f"""
사용자가 선택한 우대 조건을 고려하여 최종적으로 추천하는 상품 상위 3개는 다음과 같습니다:
{', '.join([f'{product}: {rate:.2f}%' for product, rate in top_3_products])}
"""

final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 11. 최종 추천 상품 출력
print("\n최종 추천 상품 목록:")
print(final_response['choices'][0]['message']['content'])

# %% [markdown]
# 2024/08/14

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간, 그리고 특별한 상황(예: 결혼 준비, 주택 구매, 자녀 교육 자금 마련 등)을 입력받습니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 찾은 상품을 *상품을 추천해주는 형태* 와 같이 응답합니다.
  4. 우대 조건이 있는 상품의 경우, 우대 조건들을 고객에게 알려주고, 고객이 선택한 조건에 따라 최대로 받을 수 있는 우대 금리를 계산합니다.
  5. 최종적으로 기본 금리 상품 상위 3개와 우대 조건을 고려한 상품 상위 3개를 추천합니다.

  *상품을 추천해주는 형태*
  - 우대 조건이 있는 상품 중에 최고 우대 금리가 가장 높은 상품 상위 3개를 추천합니다.
  - 우대 조건이 있는 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    '우대 조건'
    의 형태로 답변합니다.
  - 동시에 우대 조건이 없는 상품 중에 세후 이자율이 가장 높은 상품 상위 3개를 추천합니다.
  - 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    의 형태로 답변합니다.

  *특별한 상황에 따른 시나리오 예시*
  - 사용자가 "결혼 자금을 2년 내에 마련하고 싶습니다"라고 하면, 이에 맞춘 적금 상품이나 예금 상품을 추천합니다.
  - 사용자가 "내 집 마련을 위해 3년 동안 저축하고 싶습니다"라고 하면, 이에 맞춘 상품을 추천합니다.
  - 사용자가 "자녀 교육 자금을 5년 동안 모으고 싶습니다"라고 하면, 이에 맞춘 상품을 추천합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 : 저축은행, 신협, 새마을금고 등

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "나는 28살이고, 결혼 자금을 2년 내에 마련하고 싶어. 매달 50만원씩 적금을 넣을 예정이야. 어떤 상품을 추천해줄 수 있어?"

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력
print("특별한 상황에 따른 맞춤형 시나리오 및 추천 상품 목록:")

# 시나리오에 따른 상품 추천 응답
response_text = response['choices'][0]['message']['content']
print(response_text)

# 예를 들어 챗봇이 제공한 우대 조건 목록이 있다고 가정합시다.
# 예시 우대 조건 목록
bonus_conditions = {
    "1": {"조건": "자동이체", "우대 금리": 0.2},
    "2": {"조건": "급여 이체", "우대 금리": 0.3},
    "3": {"조건": "카드 사용 실적", "우대 금리": 0.1},
}

# 사용자가 선택한 우대 조건을 입력받습니다 (여기서는 예시로 사용자가 1번과 2번 조건을 선택했다고 가정)
user_selected_conditions = ["1", "2"]

# 우대 조건에 따른 금리 계산
user_bonus_rate = sum(bonus_conditions[cond]["우대 금리"] for cond in user_selected_conditions)

# 최종 추천 상품 목록 (우대 조건 포함)
print(f"\n선택한 조건에 따른 최대 우대 금리: {user_bonus_rate:.2f}%")

# Chat API를 다시 호출하여 최종 추천 상품 목록을 가져오기
final_prompt = f"""
사용자가 선택한 우대 조건을 고려하여 다음의 조건을 충족한 경우를 포함해 최종적으로 추천하는 상품 3개를 추천해주세요:
1. 기본 금리 상품 상위 3개
2. 우대 조건을 충족한 경우의 상위 3개 상품 (충족한 우대 조건: {', '.join([bonus_conditions[cond]['조건'] for cond in user_selected_conditions])})
"""

final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 최종 추천 상품 출력
print("최종 추천 상품 목록:")
print(final_response['choices'][0]['message']['content'])
# Out:
# 특별한 상황에 따른 맞춤형 시나리오 및 추천 상품 목록:
# 안녕하세요, 고객님. 결형 자금을 마련하시려는 귀하의 계획에 맞는 적금 상품을 추천해드리겠습니다.
#
# 우선, 우대 조건이 있는 상품 중에서는 다음과 같은 상품들을 추천드립니다.
#
# 1. '청춘적금 - 신한은행'
#    금리: 연 2.0%
#    가입대상: 29세 이하 청년
#    상품 안내: 매달 50만원 이하 적립 가능, 만기 시 20%의 세액공제 혜택
#    우대 조건: 신한은행 체크카드 사용시 최대 연 0.2%p 추가
#
# 2. '스마트플러스적금 - KB국민은행'
#    금리: 연 1.8%
#    가입대상: 누구나
#    상품 안내: 매달 50만원 이하 적립 가능, 만기 시 20%의 세액공제 혜택
#    우대 조건: KB국민은행 체크카드 사용시 최대 연 0.2%p 추가
#
# 3. '우리사랑적금 - 우리은행'
#    금리: 연 1.7%
#    가입대상: 누구나
#    상품 안내: 매달 50만원 이하 적립 가능, 만기 시 20%의 세액공제 혜택
#    우대 조건: 우리은행 체크카드 사용시 최대 연 0.2%p 추가
#
# 또한, 우대 조건이 없는 상품 중에서는 다음과 같은 상품들을 추천드립니다.
#
# 1. 'i-적금 - IBK기업은행'
#    금리: 연 1.5%
#    가입대상: 누구나
#    상품 안내: 매달 50만원 이하 적립 가능, 만기 시 20%의 세액공제 혜택
#
# 2. 'e-적금 - SC제일은행'
#    금리: 연 1.4%
#    가입대상: 누구나
#    상품 안내: 매달 50만원 이하 적립 가능, 만기 시 20%의 세액공제 혜택
#
# 3. '스마트e적금 - 하나은행'
#    금리: 연 1.3%
#    가입대상: 누구나
#    상품 안내: 매달 50만원 이하 적립 가능, 만기 시 20%의 세액공제 혜택
#
# 이 중에서 가장 적합하다고 생각되는 상품을 선택하시면 됩니다. 추가적으로 궁금한 점이 있으시다면 언제든지 말씀해주세요.
#
# ...

# %% [markdown]
# 주요 변경 사항 요약:
# 특별한 상황 입력: 사용자가 결혼 준비, 주택 구매, 자녀 교육 자금 마련 등 특정한 상황을 입력할 수 있도록 설계되었습니다.
#
# 상황에 맞춘 시나리오 추천: 사용자가 특정 상황을 입력하면, 그 상황에 맞춰 시나리오 기반의 금융상품을 추천합니다. 예를 들어, "결혼 자금을 2년 내에 마련"하고 싶다는 요청에 따라 적금 상품을 추천하는 등의 시나리오를 제공합니다.
#
# 우대 조건 처리: 우대 조건에 따른 최종 금리 계산을 통해 사용자가 선택한 조건에 따라 최적의 상품을 추천합니다.

# %% [markdown]
# 각 기능은 다음과 같이 설명할 수 있습니다:
#
# 1. OpenAI API 키 설정
# openai.api_key를 통해 OpenAI API를 사용할 수 있도록 API 키를 설정합니다.
# 2. 시스템 프롬프트 설정
# system_prompt 변수에 챗봇이 작동하는 기본적인 규칙과 프로세스를 설정합니다. 여기에는 사용자가 제공한 정보를 바탕으로 금융 상품을 추천하는 과정과, 특별한 상황에 맞춰 시나리오 기반으로 추천하는 방법이 포함됩니다.
# 3. 사용자 입력 처리
# user_prompt에 사용자의 요청을 예시로 설정합니다. 이 예시에서는 사용자가 결혼 자금을 2년 내에 마련하고 싶다는 상황을 설명하고 있습니다.
# 4. Chat API 호출
# openai.ChatCompletion.create를 사용하여 OpenAI API에 시스템 프롬프트와 사용자 프롬프트를 전달합니다. API는 이에 따라 금융 상품 추천 결과를 생성하고 반환합니다.
# 5. 추천 결과 출력
# response['choices'][0]['message']['content']를 통해 API가 반환한 추천 결과를 출력합니다. 여기에는 사용자가 입력한 상황에 맞는 금융 상품이 추천됩니다.
# 6. 우대 조건 목록 생성
# bonus_conditions 사전(Dictionary)에서 우대 조건의 목록과 각 조건에 따른 우대 금리를 정의합니다. 예를 들어, 자동이체를 선택하면 0.2%의 우대 금리를 제공하는 식입니다.
# 7. 사용자 선택 우대 조건 입력 및 금리 계산
# user_selected_conditions에서 사용자가 선택한 우대 조건을 리스트로 저장합니다. 이 예시에서는 사용자가 자동이체와 급여 이체 조건을 선택했다고 가정합니다.
# 사용자가 선택한 우대 조건을 바탕으로 우대 금리를 계산합니다 (user_bonus_rate).
# 8. 최종 추천 상품 목록 생성
# 사용자가 선택한 우대 조건을 반영한 최종 추천 상품 목록을 생성하기 위해 추가적인 API 호출을 수행합니다. 이 때, 우대 조건이 적용된 최종 금리와 함께 추천 결과를 생성합니다.
# 9. 최종 추천 상품 출력
# API가 반환한 최종 추천 상품 목록을 출력합니다. 이 목록에는 기본 금리가 높은 상품과 우대 조건을 고려한 상위 3개의 상품이 포함됩니다.
#
#
# 요약:
# 이 코드는 사용자가 입력한 특별한 상황(예: 결혼 자금 마련, 주택 구매 등)에 맞춰 적절한 금융 상품(예: 적금, 예금)을 추천해주는 챗봇을 구현합니다. 우대 조건을 선택할 수 있도록 하고, 그에 따른 금리 계산도 함께 제공하여 사용자가 최적의 상품을 선택할 수 있도록 돕습니다.

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간, 투자 성향(리스크 허용 범위)을 입력받습니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 리스크 성향에 따라 추천 상품을 다르게 제시합니다.
  4. 사용자가 선택한 우대 조건을 고려하여 최종적으로 추천하는 상품 상위 3개를 제공합니다.
  5. 사용자에게 재정 관리에 대한 간단한 피드백을 제공합니다.

  *리스크 성향 예시*
  - 'low': 안전성을 중시하는 경우, 안정적인 적금 상품을 추천합니다.
  - 'medium': 적당한 리스크를 감수하고자 하는 경우, 수익과 안정성을 고려한 상품을 추천합니다.
  - 'high': 높은 수익을 추구하며 리스크를 감수할 의향이 있는 경우, 고수익 상품을 추천합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 : 저축은행, 신협, 새마을금고 등

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "나는 28살이고, 결혼 자금을 2년 내에 마련하고 싶어. 매달 50만원씩 적금을 넣을 예정이야. 나의 투자 성향은 'medium'이야. 어떤 상품을 추천해줄 수 있어?"

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력
print("리스크 성향에 따른 맞춤형 시나리오 및 추천 상품 목록:")

# 시나리오에 따른 상품 추천 응답
response_text = response['choices'][0]['message']['content']
print(response_text)

# 예를 들어 챗봇이 제공한 우대 조건 목록이 있다고 가정합시다.
# 예시 우대 조건 목록
bonus_conditions = {
    "1": {"조건": "자동이체", "우대 금리": 0.2},
    "2": {"조건": "급여 이체", "우대 금리": 0.3},
    "3": {"조건": "카드 사용 실적", "우대 금리": 0.1},
}

# 사용자가 선택한 우대 조건을 입력받습니다 (여기서는 예시로 사용자가 1번과 2번 조건을 선택했다고 가정)
user_selected_conditions = ["1", "2"]

# 우대 조건에 따른 금리 계산
user_bonus_rate = sum(bonus_conditions[cond]["우대 금리"] for cond in user_selected_conditions)

# 최종 추천 상품 목록 (우대 조건 포함)
print(f"\n선택한 조건에 따른 최대 우대 금리: {user_bonus_rate:.2f}%")

# Chat API를 다시 호출하여 최종 추천 상품 목록을 가져오기
final_prompt = f"""
사용자가 선택한 우대 조건을 고려하여 다음의 조건을 충족한 경우를 포함해 최종적으로 추천하는 상품 3개를 추천해주세요:
1. 기본 금리 상품 상위 3개
2. 우대 조건을 충족한 경우의 상위 3개 상품 (충족한 우대 조건: {', '.join([bonus_conditions[cond]['조건'] for cond in user_selected_conditions])})
3. 사용자의 리스크 성향에 맞는 추천 상품 (리스크 성향: 'medium')
"""

final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 최종 추천 상품 출력
print("최종 추천 상품 목록:")
print(final_response['choices'][0]['message']['content'])
# Out:
# 리스크 성향에 따른 맞춤형 시나리오 및 추천 상품 목록:
# 안녕하세요, 고객님. 결혼 자금을 위한 적금 상품에 관심을 가져주셔서 감사합니다. 고객님의 요청사항을 바탕으로 적합한 상품을 찾아보았습니다.
#
# 1. 'KB국민은행 Liiv 적금': 이 상품은 매달 50만원씩 저축하실 수 있으며, 2년 동안 저축하시면 만기 시 연 1.85%의 이자를 받으실 수 있습니다.
#
# 2. '신한은행 S-적금': 이 상품은 고객님께서 원하시는 기간 동안 매달 50만원씩 저축하실 수 있으며, 만기 시 연 1.80%의 이자를 받으실 수 있습니다.
#
# 3. '하나은행 1Q 정기적금': 이 상품은 매달 50만원씩 저축하실 수 있으며, 2년 동안 저축하시면 만기 시 연 1.78%의 이자를 받으실 수 있습니다.
#
# 이 세 가지 상품 모두 안정적인 수익률을 보장하며, 고객님의 중간 리스크 투자 성향에 적합합니다. 각 상품의 세부적인 우대 조건이나 제한 사항은 해당 은행에 문의하시는 것이 가장 정확합니다.
#
# 그리고 저축을 시작하시는 것은 아주 좋은 결정입니다. 하지만 금융 상품에 모든 자금을 투자하기 보다는 비상금도 준비해두시는 것을 권장드립니다. 이는 급작스러운 상황에 대비하실 수 있게 도와드릴 것입니다.
#
# 더 궁금하신 점이 있으시다면 언제든지 문의해주세요. 감사합니다.
#
# 선택한 조건에 따른 최대 우대 금리: 0.50%
# 최종 추천 상품 목록:
# 안녕하세요, 고객님. 요청하신 조건에 맞는 상품을 찾아봤습니다. 아래에 추천 상품을 안내드리겠습니다.
#
# 1. 기본 금리 상품 상위 3개
#    - KB국민은행 스타 정기예금: 기본 금리 1.5%, 1년 만기
#    - 신한은행 S클래스 정기예금: 기본 금리 1.4%, 1년 만기
#    - 하나은행 We 정기예금: 기본 금리 1.3%, 1년 만기
#
# 2. 우대 조건을 충족한 경우의 상위 3개 상품
# ...

# %% [markdown]
# 추가된 내용 설명:
#
#
# 리스크 성향 입력:
#
# user_prompt에서 사용자의 투자 성향(리스크 허용 범위)을 입력받습니다. 예시에서는 사용자가 'medium' 리스크 성향을 가지고 있다고 가정했습니다.
#
#
# 리스크 성향에 따른 추천:
#
# system_prompt에 리스크 성향에 따른 상품 추천 방식에 대한 정보를 추가했습니다. 사용자의 리스크 성향에 따라 적합한 상품을 추천할 수 있도록 설정하였습니다.
#
#
# 피드백 포함:
#
# 리스크 성향에 따라 추천된 상품과 함께 간단한 재정 관리에 대한 피드백을 제공할 수 있습니다. 이 피드백은 사용자의 리스크 성향에 맞춘 재정 관리 조언을 포함할 수 있습니다.
#
#
# 최종 추천 상품 출력:
#
# 사용자가 선택한 우대 조건과 리스크 성향을 모두 고려하여 최종적으로 추천할 상품을 제시합니다.

# %% [markdown]
# 요약:
#
# 이 코드는 사용자의 투자 성향(리스크 허용 범위)과 금융 목표에 맞추어 최적의 금융 상품을 추천하는 챗봇을 구현합니다. 또한, 사용자가 선택한 우대 조건에 따른 금리 계산을 통해 최종 금리를 반영한 상품을 제안합니다. ChatGPT를 활용하여 맞춤형 추천과 재정 관리 조언을 제공하는 기능이 포함되어 있습니다.

# %% [markdown]
# 08/19
#
# - 예시 질문 :
# 1. 고객님의 현재 나이를 알 수 있을까요?
# 2. 얼마나 적금을 하실 계획인가요?
# 3. 계약하실 기간은 얼마나 되실까요?
# 4. 특정 은행에 가입하고 싶으신가요? 있다면 어떤 은행이신가요?
# 5. 저장하실 빈도는 어떠한 방식을 원하시나요? (월간, 분기별, 연간)
# 6. 세금이나 관련하여 고려하실 사항이 있으신가요?
# 7. 특별히 원하시는 우대 혜택이 있으신가요?
# 8. 특정 금리 이상을 원하시나요?
# 이러한 질문들을 통해 고객님에게 맞춤형 적금 상품을 추천해드리도록 하겠습니다.
#
#
#
# - 예시 시나리오
# 1. 군인
# 상황 설명: "저는 현재 군복무 중인 23세 남성입니다. 군 복무 기간 동안 급여를 모아 나중에 한꺼번에 사용할 계획입니다. 매달 30만 원씩 1년간 적금을 넣으려고 하는데, 군인을 위한 특별한 혜택이 있는 상품이 있는지 궁금합니다."
#
# 2. 예비 신랑
# 상황 설명: "저는 곧 결혼을 앞두고 있는 30세 남성입니다. 결혼 준비를 위해 2년 동안 매달 일정 금액을 적금으로 모으고 싶습니다. 신혼부부를 위한 특별한 혜택이나 이율이 높은 상품이 있으면 추천해 주세요."
#
# 3. 대학생
# 상황 설명: "저는 21세 대학생입니다. 아르바이트로 모은 돈을 안전하게 예치하고 싶습니다. 한 학기 동안 사용하지 않을 돈 100만 원을 6개월 동안 예금하려고 합니다. 대학생에게 유리한 조건의 예금 상품이 있을까요?"
#
# 4. 프리랜서
# 상황 설명: "저는 35세 프리랜서입니다. 소득이 일정하지 않기 때문에 여유 자금을 활용해 6개월 동안 예금에 넣어둘 계획입니다. 매달 얼마를 예금에 추가할지 유동적일 수 있는데, 유리한 조건의 예금 상품이 있을까요?"
#
# 5. 은퇴를 앞둔 중년
# 상황 설명: "저는 55세이며, 5년 내에 은퇴를 계획하고 있습니다. 퇴직금 일부를 3년 동안 예금에 넣어 두고 안정적인 이자를 받고 싶습니다. 중장년층에게 유리한 예금 상품이 있는지 알고 싶습니다."
#
# 6. 자녀의 학자금 마련
# 상황 설명: "저는 40대 초반의 부모입니다. 자녀의 대학 학자금을 위해 10년 동안 꾸준히 적금을 넣으려고 합니다. 장기적으로 높은 이율을 제공하는 적금 상품이 있으면 추천해 주세요."

# %%
import openai

# 1. OpenAI API 키 설정 (주의: 실제로는 환경 변수나 안전한 저장소에 보관)
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간 등 입니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 찾은 상품을 *상품을 추천해주는 형태* 와 같이 응답합니다.
  4. 우대 조건이 있는 상품의 경우, 우대 조건들을 고객에게 알려주고, 고객이 선택한 조건에 따라 최대로 받을 수 있는 우대 금리를 계산합니다.
  5. 최종적으로 기본 금리 상품 상위 3개와 우대 조건을 고려한 상품 상위 3개를 추천합니다.

  *상품을 추천해주는 형태*
  - 우대 조건이 있는 상품 중에 최고 우대 금리가 가장 높은 상품 상위 3개를 추천합니다.
  - 우대 조건이 있는 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    '우대 조건'
    의 형태로 답변합니다.
  - 동시에 우대 조건이 없는 상품 중에 세후 이자율이 가장 높은 상품 상위 3개를 추천합니다.
  - 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    의 형태로 답변합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 :

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "예,적금 상품 추천을 위한 내가 할 수 있는 질문들은 어떤 것들이 있을까?"

# OpenAI API를 사용하여 응답 생성
response = openai.ChatCompletion.create(
  model="gpt-4",
  messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]
)

# 응답 출력
print(response['choices'][0]['message']['content'])
# Out:
# 1. 고객님의 현재 나이를 알 수 있을까요?
# 2. 얼마나 적금을 하실 계획인가요?
# 3. 계약하실 기간은 얼마나 되실까요?
# 4. 특정 은행에 가입하고 싶으신가요? 있다면 어떤 은행이신가요?
# 5. 저장하실 빈도는 어떠한 방식을 원하시나요? (월간, 분기별, 연간)
# 6. 세금이나 관련하여 고려하실 사항이 있으신가요?
# 7. 특별히 원하시는 우대 혜택이 있으신가요?
# 8. 특정 금리 이상을 원하시나요?
# 이러한 질문들을 통해 고객님에게 맞춤형 적금 상품을 추천해드리도록 하겠습니다.

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간, 투자 성향(리스크 허용 범위)을 입력받습니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 리스크 성향에 따라 추천 상품을 다르게 제시합니다.
  4. 사용자가 선택한 우대 조건을 고려하여 최종적으로 추천하는 상품 상위 3개를 제공합니다.
  5. 사용자에게 재정 관리에 대한 간단한 피드백을 제공합니다.

  *리스크 성향 예시*
  - 'low': 안전성을 중시하는 경우, 안정적인 적금 상품을 추천합니다.
  - 'medium': 적당한 리스크를 감수하고자 하는 경우, 수익과 안정성을 고려한 상품을 추천합니다.
  - 'high': 높은 수익을 추구하며 리스크를 감수할 의향이 있는 경우, 고수익 상품을 추천합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 : 저축은행, 신협, 새마을금고 등

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "저는 현재 군복무 중인 23세 남성입니다. 군 복무 기간 동안 급여를 모아 나중에 한꺼번에 사용할 계획입니다. 매달 30만 원씩 1년간 적금을 넣으려고 하는데, 군인을 위한 특별한 혜택이 있는 상품이 있는지 궁금합니다."

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력
print("리스크 성향에 따른 맞춤형 시나리오 및 추천 상품 목록:")

# 시나리오에 따른 상품 추천 응답
response_text = response['choices'][0]['message']['content']
print(response_text)

# 예를 들어 챗봇이 제공한 우대 조건 목록이 있다고 가정합시다.
# 예시 우대 조건 목록
bonus_conditions = {
    "1": {"조건": "자동이체", "우대 금리": 0.2},
    "2": {"조건": "급여 이체", "우대 금리": 0.3},
    "3": {"조건": "카드 사용 실적", "우대 금리": 0.1},
}

# 사용자가 선택한 우대 조건을 입력받습니다 (여기서는 예시로 사용자가 1번과 2번 조건을 선택했다고 가정)
user_selected_conditions = ["1", "2"]

# 우대 조건에 따른 금리 계산
user_bonus_rate = sum(bonus_conditions[cond]["우대 금리"] for cond in user_selected_conditions)

# 최종 추천 상품 목록 (우대 조건 포함)
print(f"\n선택한 조건에 따른 최대 우대 금리: {user_bonus_rate:.2f}%")

# Chat API를 다시 호출하여 최종 추천 상품 목록을 가져오기
final_prompt = f"""
사용자가 선택한 우대 조건을 고려하여 다음의 조건을 충족한 경우를 포함해 최종적으로 추천하는 상품 3개를 추천해주세요:
1. 기본 금리 상품 상위 3개
2. 우대 조건을 충족한 경우의 상위 3개 상품 (충족한 우대 조건: {', '.join([bonus_conditions[cond]['조건'] for cond in user_selected_conditions])})
3. 사용자의 리스크 성향에 맞는 추천 상품 (리스크 성향: 'medium')
"""

final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 최종 추천 상품 출력
print("최종 추천 상품 목록:")
print(final_response['choices'][0]['message']['content'])
# Out:
# 리스크 성향에 따른 맞춤형 시나리오 및 추천 상품 목록:
# 안녕하세요, 고객님. 군복무 중이시라니 대단하십니다. 군인분들을 위한 특별한 혜택이 있는 상품에 대해 알아보겠습니다.
#
# 1. 우리은행의 '군인적금': 군인 고객을 대상으로 한 상품으로, 가입 시 우대금리가 적용되며, 가입 기간 동안 금리가 변동하지 않아 안정적인 수익을 기대할 수 있습니다.
#
# 2. KB국민은행의 '군인전용 적금': 군인 고객만을 대상으로 하는 상품으로, 가입 시점의 금리가 유지되어 금리 변동에 따른 리스크를 줄일 수 있습니다.
#
# 3. 신한은행의 '군인전용 적금': 군인 고객에게 우대금리를 제공하며, 적금 만기 시 추가 우대금리를 제공하는 특징이 있습니다.
#
# 이 외에도 다양한 은행에서 군인을 위한 적금 상품을 제공하고 있습니다. 각 은행의 상품을 비교해보시고, 가장 적합한 상품을 선택하시는 것이 좋습니다.
#
# 또한, 군인으로서의 특별한 혜택을 받기 위해서는 군인 신분을 증명할 수 있는 서류를 제출해야 합니다. 이 점 꼭 참고하시기 바랍니다.
#
# 마지막으로, 적금은 안정적인 재테크 방법이지만 수익률이 낮은 편입니다. 따라서 복무 후의 목표에 따라 다른 투자 방법도 고려해보시는 것이 좋습니다. 예를 들어, 장기적인 투자 목표가 있다면 주식이나 펀드 등을 고려해보시는 것도 좋습니다.
#
# 선택한 조건에 따른 최대 우대 금리: 0.50%
# 최종 추천 상품 목록:
# 안녕하세요, 고객님. 요청하신 조건에 따라 상품을 추천해드리겠습니다.
#
# 1. 기본 금리 상품 상위 3개
#    - KB국민은행 'KB Star 정기예금': 기본 금리가 높고, 만기 시 우대금리까지 적용되어 수익률이 높습니다.
#    - NH농협은행 'NH Smart 정기예금': 기본 금리가 높으며, 농협은행의 다양한 서비스를 이용하실 수 있습니다.
#    - 신한은행 'S-정기예금': 기본 금리가 높으며, 신한은행의 다양한 서비스를 이용하실 수 있습니다.
#
# ...

# %% [markdown]
# 08/20

# %%
pip install openai langchain langsmith
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 20.8 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade openai langchain langsmith langchain-community
# Out:
# ...
#   Using cached openai-1.42.0-py3-none-any.whl.metadata (22 kB)
# ...
# Using cached openai-1.42.0-py3-none-any.whl (362 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# ...

# %%
pip install -U langchain-openai

# %%
pip install openai==0.28
# Out:
# ...
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached openai-0.28.0-py3-none-any.whl (76 kB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.42.0
#     Uninstalling openai-1.42.0:
#       Successfully uninstalled openai-1.42.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.1.22 requires openai<2.0.0,>=1.40.0, but you have openai 0.28.0 which is incompatible.
# ...

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
당신은 대한민국에서 활동하는 금융 상담 전문가입니다. 당신의 주요 업무는 고객에게 적합한 예금, 적금, 파킹통장 상품을 추천해주는 것입니다. 당신은 금융 상품에 대한 깊은 지식과 경험을 바탕으로, 고객의 상황과 요구에 맞는 최적의 상품을 제시합니다.

고객과의 대화는 다음과 같은 프로세스를 따릅니다:

1. **고객 정보 수집**:
    - 나이, 성별, 직업 등의 인적 사항
    - 예금 또는 적금을 희망하는 금액 및 기간
    - 투자 성향 (리스크 허용 범위: 낮음, 보통, 높음)
    - 특별히 선호하는 금융기관이나 상품 유형

2. **금융 상품 분석**:
    - 고객의 투자 성향 및 요구사항에 맞는 금융 상품을 선별합니다.
    - 각 상품의 금리, 조건, 리스크 등을 평가하여 고객에게 가장 적합한 상품을 제안합니다.
    - 고객이 특정 금융기관 또는 우대 조건을 선호하는 경우, 이를 반영하여 추천합니다.

3. **맞춤형 추천**:
    - 고객의 리스크 성향에 따라 상품을 다르게 추천합니다:
        - **낮은 리스크 성향 (low)**: 안정성이 높은 예금 및 적금 상품을 추천합니다.
        - **보통 리스크 성향 (medium)**: 수익성과 안정성을 모두 고려한 균형 잡힌 상품을 추천합니다.
        - **높은 리스크 성향 (high)**: 높은 수익을 기대할 수 있는 고수익 상품을 추천합니다.

4. **우대 조건 고려**:
    - 고객이 선택한 우대 조건(예: 자동이체, 급여이체, 카드 사용 실적 등)을 바탕으로, 금리 및 혜택이 최대화되는 상품을 추천합니다.
    - 고객에게 우대 조건 충족 시 얻을 수 있는 추가 혜택에 대해 설명합니다.

5. **재정 관리 피드백**:
    - 고객의 재정 상황을 고려하여, 적절한 재정 관리 방법에 대한 간단한 피드백을 제공합니다.
    - 고객이 향후 재정 계획을 더욱 효과적으로 세울 수 있도록 조언합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 : 저축은행, 신협, 새마을금고 등

  **상담 태도**:
- 당신은 항상 친절하고, 고객의 상황을 공감하며, 고객의 이해를 돕기 위해 명확하고 쉽게 설명합니다.
- 언제나 존댓말을 사용하며, 고객이 만족할 수 있도록 최선을 다합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "저는 현재 군복무 중인 23세 남성입니다. 군 복무 기간 동안 급여를 모아 나중에 한꺼번에 사용할 계획입니다. 매달 30만 원씩 1년간 적금을 넣으려고 하는데, 군인을 위한 특별한 혜택이 있는 상품이 있는지 궁금합니다."

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력
print("리스크 성향에 따른 맞춤형 시나리오 및 추천 상품 목록:")

# 시나리오에 따른 상품 추천 응답
response_text = response['choices'][0]['message']['content']
print(response_text)

# 예를 들어 챗봇이 제공한 우대 조건 목록이 있다고 가정합시다.
# 예시 우대 조건 목록
bonus_conditions = {
    "1": {"조건": "자동이체", "우대 금리": 0.2},
    "2": {"조건": "급여 이체", "우대 금리": 0.3},
    "3": {"조건": "카드 사용 실적", "우대 금리": 0.1},
}

# 사용자가 선택한 우대 조건을 입력받습니다 (여기서는 예시로 사용자가 1번과 2번 조건을 선택했다고 가정)
user_selected_conditions = ["1", "2"]

# 우대 조건에 따른 금리 계산
user_bonus_rate = sum(bonus_conditions[cond]["우대 금리"] for cond in user_selected_conditions)

# 최종 추천 상품 목록 (우대 조건 포함)
print(f"\n선택한 조건에 따른 최대 우대 금리: {user_bonus_rate:.2f}%")

# Chat API를 다시 호출하여 최종 추천 상품 목록을 가져오기
final_prompt = f"""
사용자가 선택한 우대 조건을 고려하여 다음의 조건을 충족한 경우를 포함해 최종적으로 추천하는 상품 3개를 추천해주세요:
1. 기본 금리 상품 상위 3개
2. 우대 조건을 충족한 경우의 상위 3개 상품 (충족한 우대 조건: {', '.join([bonus_conditions[cond]['조건'] for cond in user_selected_conditions])})
3. 사용자의 리스크 성향에 맞는 추천 상품 (리스크 성향: 'medium')
"""

final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 최종 추천 상품 출력
print("최종 추천 상품 목록:")
print(final_response['choices'][0]['message']['content'])
# Out:
# 리스크 성향에 따른 맞춤형 시나리오 및 추천 상품 목록:
# 안녕하세요, 고객님. 군복무 중인 상황에서 재정 계획을 세우시려는 모습이 대단하시네요.
#
# 군인을 위한 특별 혜택을 제공하는 금융 상품에는 '군인전용적금'이 있습니다. 이 상품은 국방부와 금융감독원이 함께 운영하는 상품으로, 일반 적금보다 높은 금리를 제공하며, 군인이라는 특성을 고려해 다양한 혜택을 제공합니다.
#
# 예를 들어, KB국민은행의 'KB Star 군인전용적금'은 일반 적금 대비 높은 금리를 제공하며, 만기 시에는 적립금액의 10%를 추가로 지급하는 혜택이 있습니다. 또한, NH농협은행의 '군인전용적금'도 일반 적금보다 높은 금리를 제공하며, 적립 기간 동안 이자가 발생하지 않아 소득세를 부담하지 않아도 됩니다.
#
# 고객님께서는 매달 30만 원씩 1년간 적립하시려고 하시니, 이러한 군인전용적금 상품들을 참고하시면 좋을 것 같습니다. 그러나 각 은행마다 제공하는 금리와 혜택이 다르므로, 꼼꼼히 비교하시고 가장 적합한 상품을 선택하시는 것이 중요합니다.
#
# 또한, 군인전용적금 외에도 일부 은행에서는 군인을 위한 특별 대출 상품도 제공하고 있으니, 필요하실 경우 이용하실 수 있습니다.
#
# 금융 상품 선택에 있어서 고객님의 상황과 목표를 최우선으로 고려하시는 것이 중요하며, 꼭 본인에게 맞는 상품을 선택하시길 바랍니다. 더 궁금하신 점이 있으시면 언제든지 문의해주세요.
#
# 선택한 조건에 따른 최대 우대 금리: 0.50%
# 최종 추천 상품 목록:
# 고객님의 요구사항을 고려하여, 다음의 상품을 추천드립니다:
#
# 1. **기본 금리 상품 상위 3개**:
#     - **KB국민은행 스타 정기예금**: 안정적인 수익률과 높은 신뢰도를 자랑하는 상품입니다.
#     - **신한은행 S예금**: 높은 기본 금리와 다양한 우대 금리를 제공하는 상품입니다.
#     - **하나은행 We 정기예금**: 저렴한 최소 가입 금액과 높은 기본 금리를 제공하는 상품입니다.
#
# ...

# %%
import openai

# 1. OpenAI API 키 설정
openai.api_key = ''

# 시스템 프롬프트 설정
system_prompt = """
당신은 대한민국에서 활동하는 금융 상담 전문가입니다. 당신의 주요 업무는 고객에게 적합한 예금, 적금, 파킹통장 상품을 추천해주는 것입니다. 당신은 금융 상품에 대한 깊은 지식과 경험을 바탕으로, 고객의 상황과 요구에 맞는 최적의 상품을 제시합니다.

고객과의 대화는 다음과 같은 프로세스를 따릅니다:

1. **고객 정보 수집**:
    - 나이, 성별, 직업 등의 인적 사항
    - 예금 또는 적금을 희망하는 금액 및 기간
    - 투자 성향 (리스크 허용 범위: 낮음, 보통, 높음)
    - 특별히 선호하는 금융기관이나 상품 유형

2. **금융 상품 분석**:
    - 고객의 투자 성향 및 요구사항에 맞는 금융 상품을 선별합니다.
    - 각 상품의 금리, 조건, 리스크 등을 평가하여 고객에게 가장 적합한 상품을 제안합니다.
    - 고객이 특정 금융기관 또는 우대 조건을 선호하는 경우, 이를 반영하여 추천합니다.

3. **맞춤형 추천**:
    - 고객의 리스크 성향에 따라 상품을 다르게 추천합니다:
        - **낮은 리스크 성향 (low)**: 안정성이 높은 예금 및 적금 상품을 추천합니다.
        - **보통 리스크 성향 (medium)**: 수익성과 안정성을 모두 고려한 균형 잡힌 상품을 추천합니다.
        - **높은 리스크 성향 (high)**: 높은 수익을 기대할 수 있는 고수익 상품을 추천합니다.

4. **우대 조건 고려**:
    - 고객이 선택한 우대 조건(예: 자동이체, 급여이체, 카드 사용 실적 등)을 바탕으로, 금리 및 혜택이 최대화되는 상품을 추천합니다.
    - 고객에게 우대 조건 충족 시 얻을 수 있는 추가 혜택에 대해 설명합니다.

5. **재정 관리 피드백**:
    - 고객의 재정 상황을 고려하여, 적절한 재정 관리 방법에 대한 간단한 피드백을 제공합니다.
    - 고객이 향후 재정 계획을 더욱 효과적으로 세울 수 있도록 조언합니다.

**금융 상품의 특성**:
- 1금융권: KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
- 2금융권: 저축은행, 신협, 새마을금고 등

**상담 태도**:
- 당신은 항상 친절하고, 고객의 상황을 공감하며, 고객의 이해를 돕기 위해 명확하고 쉽게 설명합니다.
- 언제나 존댓말을 사용하며, 고객이 만족할 수 있도록 최선을 다합니다.
"""

# 사용자 프롬프트 (줄글 형식)
user_prompt = """
저는 23세 남성으로 현재 군인입니다. 매달 30만 원씩 1년간 적금을 넣을 계획입니다.
투자 성향은 보통이며, 특정 금융기관을 선호하지는 않습니다.
군인을 위한 특별한 혜택이 있는 적금 상품을 추천해 주실 수 있나요?
"""

# 첫 번째 Chat API 호출: 기본 금리 조건 상위 3개 상품 추천
basic_rate_prompt = """
고객의 정보와 요구에 맞는 기본 금리 조건 상위 3개 적금 상품을 추천해 주세요.
응답 형식:
- '1., 2., 3.' 형식으로 나열
- 각 항목에 '상품명', '금융기관', '기본 금리', '주요 혜택' 포함
"""

response_basic = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": basic_rate_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 응답 출력: 기본 금리 조건 상위 3개 상품
print("▶ 기본 금리 조건 상위 3개 상품:")
print(response_basic['choices'][0]['message']['content'])

# 우대 조건 목록
bonus_conditions = {
    "1": {"조건": "자동이체", "우대 금리": 0.2},
    "2": {"조건": "급여이체", "우대 금리": 0.3},
    "3": {"조건": "카드 사용 실적", "우대 금리": 0.1},
}

# 사용자가 선택한 우대 조건 (예시)
user_selected_conditions = ["1", "2"]

# 우대 금리 합산
user_bonus_rate = sum(bonus_conditions[cond]["우대 금리"] for cond in user_selected_conditions)

# 선택한 우대 조건 설명 생성
selected_conditions_description = ', '.join([bonus_conditions[cond]["조건"] for cond in user_selected_conditions])

# 최종 추천 상품 요청 프롬프트 생성
final_prompt = f"""
고객의 정보와 선택한 우대 조건({selected_conditions_description})을 반영하여 최적의 적금 상품 3개를 추천해 주세요.
응답 형식:
- '1., 2., 3.' 형식으로 나열
- 각 항목에 '상품명', '금융기관', '기본 금리', '우대 금리', '총 금리', '주요 혜택' 포함
"""

# 두 번째 Chat API 호출: 우대 조건을 반영한 최종 추천
final_response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": final_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5,
    top_p=0.8,
)

# 최종 추천 상품 출력: 우대 조건을 반영한 상위 3개 상품
print("\n▶ 우대 조건을 반영한 상위 3개 상품:")
print(final_response['choices'][0]['message']['content'])
# Out:
# ▶ 기본 금리 조건 상위 3개 상품:
# 고객님의 상황을 고려하여, 군인을 위한 특별 혜택이 있는 적금 상품을 추천드리겠습니다.
#
# 1. '국민은행 군인우대 적금'
#    - 금융기관: KB국민은행
#    - 기본 금리: 연 1.80%
#    - 주요 혜택: 군인 고객님들을 위한 적금 상품으로, 우대 금리를 적용받을 수 있습니다.
#
# 2. '신한은행 군인전용 적금'
#    - 금융기관: 신한은행
#    - 기본 금리: 연 1.75%
#    - 주요 혜택: 군인 고객님들을 위한 적금 상품으로, 우대 금리 및 별도의 혜택을 제공합니다.
#
# 3. '하나은행 군인 적금'
#    - 금융기관: 하나은행
#    - 기본 금리: 연 1.70%
#    - 주요 혜택: 군인 고객님들을 위한 적금 상품으로, 우대 금리를 적용받을 수 있으며, 별도의 혜택을 제공합니다.
#
# 이 중에서 고객님의 상황에 가장 적합한 상품을 선택하시면 됩니다. 각 금융기관의 상세한 우대 조건 및 혜택은 직접 문의하시는 것이 가장 정확합니다.
#
# ▶ 우대 조건을 반영한 상위 3개 상품:
# 네, 군인 고객님을 위한 적금 상품을 추천해드리겠습니다. 군인 고객님께서는 군인 전용 상품을 이용하실 수 있으며, 이는 일반 상품보다 높은 금리 혜택을 받으실 수 있습니다.
#
# 1. '군인전용 적금'
#     - 금융기관: 국민은행
#     - 기본 금리: 1.50%
#     - 우대 금리: 0.2% (군인 전용 우대)
#     - 총 금리: 1.70%
#     - 주요 혜택: 군인이라는 직업 특성을 고려하여, 입대 및 전역 시점에 따른 유예 기간을 제공합니다.
#
# 2. '우리 군인 적금'
#     - 금융기관: 우리은행
#     - 기본 금리: 1.40%
#     - 우대 금리: 0.2% (군인 전용 우대)
#     - 총 금리: 1.60%
# ...

# %% [markdown]
# 이 코드는 사용자에게 맞춤형 금융 상품을 추천하는 챗봇을 구현한 것입니다. 주요 단계는 다음과 같습니다:
#
# API 설정: OpenAI API 키 설정.
# 프롬프트 설정: 챗봇의 역할과 사용자가 입력한 정보를 기반으로 시스템 프롬프트와 사용자 프롬프트를 설정.
# 기본 금리 상품 추천: 기본 금리가 높은 상위 3개 상품을 추천.
# 우대 조건 반영: 사용자가 선택한 우대 조건을 반영하여 상위 3개 상품을 다시 추천.
# 이 코드는 사용자가 입력한 정보를 바탕으로, 최적의 금융 상품을 찾고 추천하는 데 중점을 둔 기능을 제공합니다. 이를 통해 챗봇이 다양한 사용자의 요구에 맞춰 맞춤형 금융 상품 추천을 효율적으로 제공할 수 있습니다.

# %% [markdown]
# 안녕하세요, 오늘 저는 OpenAI의 ChatGPT API를 활용하여 금융 상담 시나리오를 구현한 사례를 소개하고, 이 과정에서 사용된 프롬프트 엔지니어링에 대해 중점적으로 설명드리고자 합니다.
#
#
# 프롬프트 엔지니어링의 중요성:
#
# 프롬프트 엔지니어링은 AI 모델이 원하는 결과를 도출하도록 유도하는 핵심 기술입니다. ChatGPT와 같은 언어 모델은 주어진 입력, 즉 '프롬프트'에 따라 다양한 반응을 생성할 수 있습니다. 따라서, 원하는 결과를 얻기 위해서는 프롬프트를 효과적으로 설계하는 것이 매우 중요합니다. 이번 사례에서도 이러한 프롬프트 엔지니어링이 성공적인 금융 상담 시나리오 구현의 핵심이 되었습니다.
#
#
# 1. 시스템 프롬프트 설정:
#
# 먼저, 시스템 프롬프트를 통해 ChatGPT가 금융 상담 전문가로서 작동하도록 설정했습니다. 이 프롬프트는 모델의 역할을 명확히 정의하고, 상담 과정에서 어떤 정보를 수집하고 분석해야 하는지를 지시합니다. 예를 들어, 고객의 나이, 성별, 직업 등 인적 사항과 예금 또는 적금 희망 금액 및 기간, 투자 성향 등을 수집하도록 지정했습니다. 이러한 정보는 ChatGPT가 적합한 금융 상품을 추천하는 데 필수적입니다.
#
# 또한, 모델이 금융 상품을 분석할 때 고려해야 할 금리, 조건, 리스크 등의 요소를 명시했습니다. 이렇게 구체적으로 지시함으로써, ChatGPT가 고객의 상황에 맞는 맞춤형 추천을 할 수 있도록 유도했습니다.
#
#
# 2. 사용자 프롬프트 설정:
#
# 사용자 프롬프트에서는 고객의 구체적인 상황을 기반으로 ChatGPT가 적절한 금융 상품을 추천할 수 있도록 설정했습니다. 예를 들어, 23세 남성 군인이 매달 30만 원씩 1년간 적금을 넣으려는 계획을 가지고 있으며, 투자 성향이 보통이라는 정보를 제공했습니다. 이때 특정 금융기관을 선호하지 않는다는 점도 프롬프트에 포함시켜, 모델이 다양한 금융기관의 상품을 고려할 수 있도록 했습니다.
#
# 이 프롬프트를 통해 ChatGPT는 고객의 요구에 맞는 기본 금리 조건이 좋은 상위 3개 적금 상품을 추천하게 됩니다. 여기서 중요한 것은, 고객의 투자 성향과 요구사항에 맞춘 정확한 질문을 통해 ChatGPT가 최적의 결과를 도출하도록 유도하는 것입니다.
#
#
# 3. 우대 조건과 최종 추천:
#
# 프롬프트 엔지니어링의 또 다른 중요한 부분은 우대 조건을 고려한 최종 추천 과정입니다. 고객이 선택할 수 있는 우대 조건을 설정하고, 이를 반영한 최종 금리와 상품을 추천하도록 프롬프트를 작성했습니다. 예를 들어, 자동이체, 급여이체, 카드 사용 실적 등의 조건을 추가로 고려하도록 지시했습니다.
#
# 이를 통해, ChatGPT는 우대 금리를 합산하여 최종 금리를 계산하고, 고객에게 최적의 상품을 제안합니다. 여기서 우대 조건을 반영한 최종 추천 프롬프트는, 고객이 실제로 더 나은 금융 상품을 선택할 수 있도록 정확하고 명확하게 설계되었습니다.
#
#
# 결론:
#
# 이번 사례에서 프롬프트 엔지니어링은 ChatGPT가 금융 상담 전문가로서 고객의 요구에 맞는 정확한 추천을 할 수 있도록 하는 데 중요한 역할을 했습니다. 효과적인 프롬프트 설계를 통해, 우리는 AI 모델이 복잡한 금융 상담 업무를 수행할 수 있도록 유도할 수 있었습니다. 이는 고객 맞춤형 금융 서비스를 제공하는 데 있어 큰 잠재력을 보여주며, 앞으로도 다양한 분야에서 활용 가능성을 시사합니다.
#
#
# 이상으로 발표를 마치겠습니다. 감사합니다.

# %% [markdown]
# 08/21

# %%
import sqlite3

# DB 연결
conn = sqlite3.connect('finance_products.db')
cursor = conn.cursor()

# 테이블 생성
create_table_query = """
CREATE TABLE IF NOT EXISTS products (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    상품명 TEXT,
    은행명 TEXT,
    금리 REAL,
    가입대상 TEXT,
    상품안내 TEXT,
    우대조건 TEXT,
    최고우대금리 REAL,
    세후금리 REAL
);
"""

cursor.execute(create_table_query)
conn.commit()

# 예시 데이터 삽입
insert_data_query = """
INSERT INTO products (상품명, 은행명, 금리, 가입대상, 상품안내, 우대조건, 최고우대금리, 세후금리)
VALUES
('프리미엄 적금', 'KDB산업은행', 3.5, '모든 고객', '12개월 동안 매달 일정 금액을 납입하는 적금 상품입니다.', '자동이체, 신용카드 사용실적', 3.5, 3.0),
('플러스 적금', '신한은행', 3.3, '신규 고객', '신규 고객에게 특별 금리를 제공하는 적금 상품입니다.', '급여이체, 공과금 자동납부', 3.3, 2.8),
('베이직 적금', '하나은행', 2.8, '모든 고객', '가장 기본적인 적금 상품입니다.', NULL, NULL, 2.8);
"""

cursor.execute(insert_data_query)
conn.commit()

# 연결 종료
conn.close()

# %%
import openai
import sqlite3

# 1. OpenAI API 키 설정
openai.api_key = ''

# DB 연결 설정
def connect_db(db_name="finance_products.db"):
    """데이터베이스에 연결하고 커넥션 객체를 반환합니다."""
    conn = sqlite3.connect(db_name)
    return conn

# Function 정의
def recommend_products(age, gender, amount, duration):
    conn = connect_db()
    cursor = conn.cursor()

    # 우대 조건이 있는 상품 조회
    query_preferred = """
    SELECT 상품명, 은행명, 금리, 가입대상, 상품안내, 우대조건
    FROM products
    WHERE 우대조건 IS NOT NULL
    ORDER BY 최고우대금리 DESC
    LIMIT 3
    """
    cursor.execute(query_preferred)
    preferred_products = cursor.fetchall()

    # 우대 조건이 없는 상품 조회
    query_non_preferred = """
    SELECT 상품명, 은행명, 금리, 가입대상, 상품안내
    FROM products
    WHERE 우대조건 IS NULL
    ORDER BY 세후금리 DESC
    LIMIT 3
    """
    cursor.execute(query_non_preferred)
    non_preferred_products = cursor.fetchall()

    conn.close()

    # 데이터를 사전 형식으로 변환
    preferred_products_list = [
        {
            "상품명": row[0],
            "은행명": row[1],
            "금리": row[2],
            "가입대상": row[3],
            "상품 안내": row[4],
            "우대 조건": row[5]
        }
        for row in preferred_products
    ]

    non_preferred_products_list = [
        {
            "상품명": row[0],
            "은행명": row[1],
            "금리": row[2],
            "가입대상": row[3],
            "상품 안내": row[4]
        }
        for row in non_preferred_products
    ]

    return preferred_products_list, non_preferred_products_list

# Function Calling 설정
functions = [
    {
        "name": "recommend_products",
        "description": "사용자의 정보를 기반으로 적합한 예적금 상품을 추천합니다.",
        "parameters": {
            "type": "object",
            "properties": {
                "age": {"type": "integer", "description": "사용자의 나이"},
                "gender": {"type": "string", "enum": ["남자", "여자"], "description": "사용자의 성별"},
                "amount": {"type": "integer", "description": "매달 적금할 금액"},
                "duration": {"type": "integer", "description": "적금 기간(개월 수)"}
            },
            "required": ["age", "gender", "amount", "duration"],
        },
    }
]

# 시스템 프롬프트 설정
system_prompt = """
  당신은 은행 저축은행의 예금, 적금, 파킹통장 상품을 추천해주는 에이전트입니다.
  당신은 은행 업무에 전문적입니다.

  *프로세스*
  1. 사용자에게 간단한 인적사항을 입력받습니다. 예를 들면, 나이, 예금 혹은 적금하고자 하는 금액, 기간 등 입니다.
  2. 해당 조건에 적합한 상품을 찾습니다.
  3. 찾은 상품을 *상품을 추천해주는 형태* 와 같이 응답합니다.

  *상품을 추천해주는 형태*
  - 우대 조건이 있는 상품 중에 최고 우대 금리가 가장 높은 상품 상위 3개를 추천합니다.
  - 우대 조건이 있는 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    '우대 조건'
    의 형태로 답변합니다.
  - 동시에 우대 조건이 없는 상품 중에 세후 이자율이 가장 높은 상품 상위 3개를 추천합니다.
  - 상품 추천 응답은
    '상품명 - 은행명'
    '금리'
    '가입대상'
    '상품 안내'
    의 형태로 답변합니다.

  *금융 상품의 특성*
  - 1금융권 : KDB산업은행, NH농협은행, 신한은행, 우리은행, SC제일은행, 하나은행, IBK기업은행, KB국민은행, 한국씨티은행, Sh수협은행, iM뱅크(구 대구은행), BNK부산은행, 광주은행, 제주은행, 전북은행, BNK경남은행, 케이뱅크, 카카오뱅크, 토스뱅크
  - 2금융권 :

  *성격*
  - 당신은 항상 친절한 은행상담원과 같은 성격을 가지고 있습니다.
  - 당신은 언제나 한글로 응답을 하고 언제나 존댓말을 사용합니다.
"""

# 사용자 프롬프트 예시
user_prompt = "나는 27살 남자이고, 매달 10만원 씩 적금을 12개월동안 할 거 같은데 나한테 추천해줄만한 적금 상품이 있을까 ?"

# Chat API 호출
response = openai.ChatCompletion.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    functions=functions,
    function_call="auto",  # 함수 호출을 자동으로 수행
    temperature=0.5,
    top_p=0.8,
)

# 함수 호출 결과 처리
if response['choices'][0]['finish_reason'] == 'function_call':
    function_name = response['choices'][0]['message']['function_call']['name']
    function_args = response['choices'][0]['message']['function_call']['arguments']

    # 문자열 형태의 인자를 실제 인자로 변환
    function_args = eval(function_args)

    # 함수 호출
    preferred_products, non_preferred_products = recommend_products(**function_args)

    # 출력 형식에 맞게 상품 정보 출력
    print("추천 상품 목록:")
    print("\n[우대 조건이 있는 상품]")
    for product in preferred_products:
        print(f"상품명: {product['상품명']} - 은행명: {product['은행명']}")
        print(f"금리: {product['금리']}")
        print(f"가입대상: {product['가입대상']}")
        print(f"상품 안내: {product['상품 안내']}")
        print(f"우대 조건: {product['우대 조건']}\n")

    print("\n[우대 조건이 없는 상품]")
    for product in non_preferred_products:
        print(f"상품명: {product['상품명']} - 은행명: {product['은행명']}")
        print(f"금리: {product['금리']}")
        print(f"가입대상: {product['가입대상']}")
        print(f"상품 안내: {product['상품 안내']}\n")

else:
    # 함수 호출이 아닌 경우 일반 응답 출력
    print(response['choices'][0]['message']['content'])

# %% [markdown]
# 이 코드는 사용자의 정보를 기반으로 적합한 금융 상품을 데이터베이스에서 조회하고 추천하는 챗봇 시스템을 구현한 것입니다. 기본적으로 Python과 OpenAI의 GPT API를 사용하며, 데이터베이스와 연동하여 실시간으로 금융 상품을 추천합니다.
#
# 먼저, OpenAI API 키를 설정하고, 데이터베이스와의 연결을 관리하기 위해 connect_db 함수를 정의합니다. 이 함수는 SQLite 데이터베이스에 연결하고, 커넥션 객체를 반환합니다. 이 커넥션 객체를 사용하여 데이터베이스에서 데이터를 조회합니다.
#
# recommend_products 함수는 사용자가 제공한 나이, 성별, 적금할 금액, 적금 기간 등의 정보를 바탕으로 적합한 금융 상품을 추천합니다. 이 함수는 두 가지 쿼리를 실행합니다. 첫 번째 쿼리는 우대 조건이 있는 상품 중에서 최고 우대 금리가 높은 상위 3개 상품을 조회하고, 두 번째 쿼리는 우대 조건이 없는 상품 중에서 세후 금리가 높은 상위 3개 상품을 조회합니다. 조회된 결과는 리스트 형태로 변환되어 반환됩니다.
#
# OpenAI API 호출에서는 사용자에게 제공된 정보를 기반으로, 필요시 함수 호출을 자동으로 수행하도록 설정되어 있습니다. 만약 함수 호출이 필요한 경우, recommend_products 함수가 호출되고, 해당 결과를 사용자에게 출력하는 형태로 구현되어 있습니다. 출력 시에는 우대 조건이 있는 상품과 없는 상품을 구분하여, 각각의 상품명, 은행명, 금리, 가입대상, 상품 안내, 우대 조건 등을 사용자에게 표시합니다.
#
# 이 코드는 SQLite 데이터베이스와 연동되어 있기 때문에, 실제 금융 상품 데이터를 기반으로 사용자 맞춤형 추천을 제공할 수 있습니다. 데이터베이스의 products 테이블은 금융 상품 정보를 담고 있으며, 이 테이블에서 필요한 정보를 조회하여 사용자가 요청한 조건에 맞는 금융 상품을 찾습니다.

# %%
# !pip install openai -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00

# %%
# !pip install openai==0.28.0 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.5 MB/s eta 0:00:00

# %%
# !pip install -q gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 82.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 91.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 10.0 MB/s eta 0:00:00

# %%
import gradio as gr
import openai

# OpenAI API
openai.api_key = ""

# 시스템 메시지 설정
system_message = system = """
    당신은 금융 상품 전문가입니다.
    당신의 주된 일은 사용자의 질문에 따라 맞춤형 상품을 추천합니다.
    상품과 관련해서 묻는 질문은 중학생도 알아 듣기 쉽게 설명해줍니다.

    ** 추천 방식 **

    추천하는 상품의 종류는 총 3가지로, 예금, 적금, 파킹통장이 있습니다.

    상품을 추천할 때는 기본금리가 높은 순으로 3개, 최고금리가 높은 순으로 3개를 추천합니다.

    단, 최고한도가 넘지 않는 상품을 골라 추천합니다.

    추천시 은행은 제 1금융권과 제 2금융권을 포함합니다.

    제 1금융권은 저축은행을 제외한 은행과 뱅크로 끝납니다.
    예를 들어 KB국민은행, 신한은행, 우리은행, KEB하나은행, 부산은행, 경남은행, 대구은행, 광주은행, 전북은행, 제주은행, SC제일은행, 씨티은행, 카카오뱅크, 케이뱅크, 토스뱅크, 한국은행, 수출입은행, KDB산업은행, IBK기업은행, Sh수협은행, NH농협은행입니다.


    제 2금융권은 보험회사, 증권회사, 자산운용회사, 저축은행, 상호금융기관,
    여신전문금융회사(카드사, 캐피탈) 등입니다.
    예를 들어 KB저축은행, 하나저축은행 등이 있습니다.

    사용자가 제공하는 정보를 바탕으로 가장 적절한 상품을 추천하되, 상품의 특징과 이점을 명확하게 설명합니다.

    추천을 할 때는 다음의 정보를 포함시킵니다:
    - 해당하는 상품의 은행, 상품명
    - 상품의 기본금리, 최고금리
    - 이자 계산 방식(단리인지 복리인지 알려줍니다.)
    - 적립 방식(적금인 경우에만 알려주며, 정액 적립식인지 자유 적립식인지 알려줍니다. )
    - 가입 대상
    - 개월 수
    - 가입 방법
    - 기타 유의사항

    ** 추천 형식 **
    은행과 상품명은 양 옆에 **을 붙입니다. 예를 들어 : ** 하나은행 내맘 적금 **
    한 상품의 정보를 다 알려줬다면
    다음 상품을 한줄 띄고 보여줍니다.

    기본 금리가 높은 순으로 3개를 먼저 보여주고, 최고 금리가 높은 순 3개를 보여주기전
    =으로 선을 나눕니다.
    선으로 나눌 때 =을 80개를 사용합니다.





    ** 사용자 질문 형식 **
    1. 3가지의 상품 중 하나를 골라 추천을 해달라고 할 땐 추천 방식에 따라 추천합니다.
    예를 들어, 적금을 들려고 하는데 추천해줘라고 할 경우 적금 상품 중에서 기본금리가 높은 순으로 3개, 최고금리가 높은 순으로 3개를 추천합니다.
    단, 상품명도 자세히 적어줍니다.

    2. 입출금이 쉬운 상품을 찾는다면 파킹통장을 우선으로 추천합니다. 파킹통장도 기본금리가 높은 순으로 3개, 최고금리가 높은 순으로 3개를 추천합니다.
    3. 나이와 성별을 입력했다면 가입대상에 맞춰서 추천합니다.
    4. 특정 개월 수가 아니라면 재입력을 받습니다.
    5. 원하는 특정 은행이 있다면 그 은행에서만 상품을 추천해줍니다.
    6. 사용자가 우대조건을 말할 경우 그 우대에 맞는 상품을 우선적으로 보여줍니다.
    7. 1개월동안 돈을 넣는 경우 파킹통장을 우선으로 추천합니다.
    추천시 이유를 알려줍니다.
    8. 추천시 제 1금융권과 제 2금융권 모두를 포함하지만 특정 은행이나 특정 금융권을 원한다면 특정한 곳에 속하는 상품을 추천합니다.




    ** 개월 수 제한 **
    개월 수는 1개월, 3개월, 6개월, 12개월, 24개월, 36개월이 있습니다.

    이 개월 수외에 다른 개월 수를 받으면 가능한 개월 수를 알려주고 다시 입력을 받아야 합니다.

    예를 들어 5개월동안 적금을 들려고 하는 사용자가 있다면,

    가능한 개월수는 1개월, 3개월, 6개월, 12개월, 24개월, 36개월이 있습니다.

    이중에서 선택해 주세요.라고 재 입력을 받아야 합니다.




    ** 사용자와 상호작용 **
    상담하는 말투로 상냥하고 정중하게 제안합니다. 사용자가 특정 언어를 요구하지 않는 이상 한국어로 질의응답을 합니다.



    ** 최고 금리 계산 **
    사용자가 특정 상품의 우대 조건을 궁금해 할 경우 우대 조건을 보여주고, 해당하는 번호를 입력 받습니다.

    기본 금리에 우대 금리를 합하여 알려줍니다.

    해당하는 번호를 입력 받은 후에 다음의 정보를 포함시켜 알려줍니다.:
    - 기본금리에 우대금리를 합한 금리
    - 세후 이자율

    세후 이자율 계산은 기본금리에 우대금리를 합한 금리 * 0.846을 해서 나온 결과에 소수점 한자리까지 알려줍니다.


"""

# 채팅함수
def chat_with_tutor(user_input, chat_history):
    messages = [
        {"role": "system", "content": system_message}] + chat_history

    if not chat_history:
        messages.append({"role": "user", "content": "안녕하세요! 금융상품 추천 챗봇입니다. 어떤 금융상품에 대해 알아보고 싶으신가요? 적금, 예금, 파킹통장 중 궁금한 상품을 말씀해주시면 추천해드리겠습니다!"})

    messages.append({"role": "user", "content": user_input})

    response = openai.ChatCompletion.create(
        model="gpt-4o-mini-2024-07-18",
        messages=messages,
        temperature=0.5,
        max_tokens=300,
        top_p=1,
    )

    response_msg = response.choices[0].message.content
    chat_history.append({"role": "assistant", "content": response_msg})

    return response_msg, chat_history

# Gradio UI 구성
def start_chat():
    return "안녕하세요! 어떤 금융상품을 도와드릴까요? 먼저 고객님이 원하시는 상품이나 고객님의 상황을 알려주세요!", []

with gr.Blocks() as demo:
    gr.Markdown("# 금융상품 추천 챗봇")

    chat_history = gr.State([])

    with gr.Row():
        start_button = gr.Button("추천 시작")

    tutor_response = gr.Textbox(label="챗봇의 응답")
    user_input = gr.Textbox(label="사용자의 질문")

    with gr.Row():
        submit_button = gr.Button("질문 제출")

    start_button.click(start_chat, inputs=[], outputs=[tutor_response, chat_history])
    submit_button.click(chat_with_tutor, inputs=[user_input, chat_history], outputs=[tutor_response, chat_history])

# 실행
demo.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://affdfe6ce24d96366c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://affdfe6ce24d96366c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://affdfe6ce24d96366c.gradio.live

# %% [markdown]
# 이 코드는 Gradio와 OpenAI의 GPT API를 사용하여 금융상품 추천 챗봇을 구현한 예제입니다. 이 챗봇은 사용자와 상호작용하며 적금, 예금, 파킹통장 등의 금융상품을 추천합니다.
#
# 코드 설명:
#
#
# 1. OpenAI API 설정:
#
# OpenAI API 키를 설정하여 GPT 모델과 상호작용할 수 있도록 합니다.
#
#
# 2. 시스템 메시지 설정:
#
# 챗봇이 동작하는 기본 규칙과 가이드라인을 설정합니다. 이 시스템 메시지에는 금융 상품의 추천 방식, 상호작용 규칙, 최고 금리 계산 방식 등이 포함됩니다.
#
#
# 3. 채팅 함수 (chat_with_tutor):
#
# 사용자가 입력한 질문을 기반으로 GPT 모델과 상호작용하여 답변을 생성합니다.
# messages 리스트는 시스템 메시지와 대화 기록을 포함하며, 이 메시지들을 기반으로 GPT 모델이 응답을 생성합니다.
# 생성된 응답은 대화 기록에 추가되며, 사용자에게 반환됩니다.
#
#
# 4. Gradio UI 구성:
#
# start_chat 함수는 사용자가 챗봇과의 대화를 시작할 때 초기 메시지와 빈 대화 기록을 반환합니다.
# Gradio 인터페이스는 버튼과 텍스트 박스를 통해 사용자가 챗봇과 상호작용할 수 있도록 구성됩니다.
# 사용자가 "추천 시작" 버튼을 클릭하면 start_chat 함수가 호출되어 초기 메시지를 표시합니다.
# 사용자가 질문을 제출하면 chat_with_tutor 함수가 호출되어 GPT 모델이 응답을 생성하고, 그 응답이 화면에 표시됩니다.
#
#
# 5. 앱 실행:
#
# demo.launch(debug=True)를 통해 Gradio 앱이 실행됩니다.
#
#
#
#
# 보완할 점 및 개선 방안:
#
#
# 1. API 키 보안:
#
# API 키는 코드에 직접 포함시키지 않고 환경 변수를 통해 관리하는 것이 좋습니다. 이렇게 하면 API 키가 외부에 노출될 위험을 줄일 수 있습니다.
#
#
# 2. 모델 버전 및 파라미터 최적화:
#
# 현재 모델은 "gpt-4o-mini-2024-07-18"을 사용하고 있습니다. 실제로 적용할 때는 최신 버전을 사용하는 것이 좋으며, temperature, max_tokens, top_p와 같은 파라미터를 사용자의 요구에 따라 조정할 수 있습니다.
#
#
# 3. 에러 핸들링:
#
# 사용자가 잘못된 입력을 했을 때, 예를 들어 허용되지 않은 개월 수를 입력하는 경우, 적절한 피드백을 제공하는 에러 핸들링이 필요합니다.
#
#
# 4. 응답 시간 최적화:
#
# GPT 모델을 호출하는 과정에서 응답 시간이 길어질 수 있습니다. 이를 최적화하기 위해 비동기 처리를 도입하거나 캐싱을 활용할 수 있습니다.
#
#
# 5. 다양한 입력 형식 지원:
#
# 현재는 텍스트 입력만을 처리하지만, 사용자의 편의를 위해 음성 입력이나 선택형 옵션을 제공할 수 있습니다.
#
#
# 6. 모바일 친화적 인터페이스:
#
# Gradio의 UI를 모바일에서도 쉽게 사용할 수 있도록 반응형 디자인을 고려할 수 있습니다.
#
#
# 7. 사용자 피드백 수집:
#
# 챗봇이 제공한 추천이 유용했는지에 대한 피드백을 수집하고, 이를 바탕으로 추천 알고리즘을 개선할 수 있습니다.
# 이러한 개선 방안을 통해 챗봇의 사용자 경험을 더 향상시킬 수 있을 것입니다.

# %%
import gradio as gr
import openai

# OpenAI API
openai.api_key = ""

# 허용된 개월 수 리스트
valid_months = [1, 3, 6, 12, 24, 36]

# 시스템 메시지 설정
system_message = system = """
    당신은 금융 상품 전문가입니다.
    당신의 주된 일은 사용자의 질문에 따라 맞춤형 상품을 추천합니다.
    상품과 관련해서 묻는 질문은 중학생도 알아 듣기 쉽게 설명해줍니다.

    ** 추천 방식 **

    추천하는 상품의 종류는 총 3가지로, 예금, 적금, 파킹통장이 있습니다.

    상품을 추천할 때는 기본금리가 높은 순으로 3개, 최고금리가 높은 순으로 3개를 추천합니다.

    단, 최고한도가 넘지 않는 상품을 골라 추천합니다.

    추천시 은행은 제 1금융권과 제 2금융권을 포함합니다.

    제 1금융권은 저축은행을 제외한 은행과 뱅크로 끝납니다.
    예를 들어 KB국민은행, 신한은행, 우리은행, KEB하나은행, 부산은행, 경남은행, 대구은행, 광주은행, 전북은행, 제주은행, SC제일은행, 씨티은행, 카카오뱅크, 케이뱅크, 토스뱅크, 한국은행, 수출입은행, KDB산업은행, IBK기업은행, Sh수협은행, NH농협은행입니다.


    제 2금융권은 보험회사, 증권회사, 자산운용회사, 저축은행, 상호금융기관,
    여신전문금융회사(카드사, 캐피탈) 등입니다.
    예를 들어 KB저축은행, 하나저축은행 등이 있습니다.

    사용자가 제공하는 정보를 바탕으로 가장 적절한 상품을 추천하되, 상품의 특징과 이점을 명확하게 설명합니다.

    추천을 할 때는 다음의 정보를 포함시킵니다:
    - 해당하는 상품의 은행, 상품명
    - 상품의 기본금리, 최고금리
    - 이자 계산 방식(단리인지 복리인지 알려줍니다.)
    - 적립 방식(적금인 경우에만 알려주며, 정액 적립식인지 자유 적립식인지 알려줍니다. )
    - 가입 대상
    - 개월 수
    - 가입 방법
    - 기타 유의사항

    ** 추천 형식 **
    은행과 상품명은 양 옆에 **을 붙입니다. 예를 들어 : ** 하나은행 내맘 적금 **
    한 상품의 정보를 다 알려줬다면
    다음 상품을 한줄 띄고 보여줍니다.

    기본 금리가 높은 순으로 3개를 먼저 보여주고, 최고 금리가 높은 순 3개를 보여주기전
    =으로 선을 나눕니다.
    선으로 나눌 때 =을 80개를 사용합니다.





    ** 사용자 질문 형식 **
    1. 3가지의 상품 중 하나를 골라 추천을 해달라고 할 땐 추천 방식에 따라 추천합니다.
    예를 들어, 적금을 들려고 하는데 추천해줘라고 할 경우 적금 상품 중에서 기본금리가 높은 순으로 3개, 최고금리가 높은 순으로 3개를 추천합니다.
    단, 상품명도 자세히 적어줍니다.

    2. 입출금이 쉬운 상품을 찾는다면 파킹통장을 우선으로 추천합니다. 파킹통장도 기본금리가 높은 순으로 3개, 최고금리가 높은 순으로 3개를 추천합니다.
    3. 나이와 성별을 입력했다면 가입대상에 맞춰서 추천합니다.
    4. 특정 개월 수가 아니라면 재입력을 받습니다.
    5. 원하는 특정 은행이 있다면 그 은행에서만 상품을 추천해줍니다.
    6. 사용자가 우대조건을 말할 경우 그 우대에 맞는 상품을 우선적으로 보여줍니다.
    7. 1개월동안 돈을 넣는 경우 파킹통장을 우선으로 추천합니다.
    추천시 이유를 알려줍니다.
    8. 추천시 제 1금융권과 제 2금융권 모두를 포함하지만 특정 은행이나 특정 금융권을 원한다면 특정한 곳에 속하는 상품을 추천합니다.




    ** 개월 수 제한 **
    개월 수는 1개월, 3개월, 6개월, 12개월, 24개월, 36개월이 있습니다.

    이 개월 수외에 다른 개월 수를 받으면 가능한 개월 수를 알려주고 다시 입력을 받아야 합니다.

    예를 들어 5개월동안 적금을 들려고 하는 사용자가 있다면,

    가능한 개월수는 1개월, 3개월, 6개월, 12개월, 24개월, 36개월이 있습니다.

    이중에서 선택해 주세요.라고 재 입력을 받아야 합니다.




    ** 사용자와 상호작용 **
    상담하는 말투로 상냥하고 정중하게 제안합니다. 사용자가 특정 언어를 요구하지 않는 이상 한국어로 질의응답을 합니다.



    ** 최고 금리 계산 **
    사용자가 특정 상품의 우대 조건을 궁금해 할 경우 우대 조건을 보여주고, 해당하는 번호를 입력 받습니다.

    기본 금리에 우대 금리를 합하여 알려줍니다.

    해당하는 번호를 입력 받은 후에 다음의 정보를 포함시켜 알려줍니다.:
    - 기본금리에 우대금리를 합한 금리
    - 세후 이자율

    세후 이자율 계산은 기본금리에 우대금리를 합한 금리 * 0.846을 해서 나온 결과에 소수점 한자리까지 알려줍니다.


"""

# 입력 검증 함수
def validate_input(user_input):
    # 사용자가 입력한 개월 수를 추출하는 예시 (구체적인 로직은 필요에 따라 조정 가능)
    words = user_input.split()
    for word in words:
        if word.isdigit():
            month = int(word)
            if month not in valid_months:
                return False, month
    return True, None

# 채팅함수
def chat_with_tutor(user_input, chat_history):
    is_valid, invalid_month = validate_input(user_input)

    # 잘못된 입력이 있는 경우 피드백 제공
    if not is_valid:
        response_msg = f"죄송합니다, {invalid_month}개월은 허용되지 않은 개월 수입니다. 가능한 개월 수는 1개월, 3개월, 6개월, 12개월, 24개월, 36개월입니다. 이 중에서 다시 선택해 주세요."
        chat_history.append({"role": "assistant", "content": response_msg})
        return response_msg, chat_history

    messages = [
        {"role": "system", "content": system_message}] + chat_history

    if not chat_history:
        messages.append({"role": "user", "content": "안녕하세요! 금융상품 추천 챗봇입니다. 어떤 금융상품에 대해 알아보고 싶으신가요? 적금, 예금, 파킹통장 중 궁금한 상품을 말씀해주시면 추천해드리겠습니다!"})

    messages.append({"role": "user", "content": user_input})

    response = openai.ChatCompletion.create(
        model="gpt-4o-mini-2024-07-18",
        messages=messages,
        temperature=0.5,
        max_tokens=300,
        top_p=1,
    )

    response_msg = response.choices[0].message.content
    chat_history.append({"role": "assistant", "content": response_msg})

    return response_msg, chat_history

# Gradio UI 구성
def start_chat():
    return "안녕하세요! 어떤 금융상품을 도와드릴까요? 먼저 고객님이 원하시는 상품이나 고객님의 상황을 알려주세요!", []

with gr.Blocks() as demo:
    gr.Markdown("# 금융상품 추천 챗봇")

    chat_history = gr.State([])

    with gr.Row():
        start_button = gr.Button("추천 시작")

    tutor_response = gr.Textbox(label="챗봇의 응답")
    user_input = gr.Textbox(label="사용자의 질문")

    with gr.Row():
        submit_button = gr.Button("질문 제출")

    start_button.click(start_chat, inputs=[], outputs=[tutor_response, chat_history])
    submit_button.click(chat_with_tutor, inputs=[user_input, chat_history], outputs=[tutor_response, chat_history])

# 실행
demo.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://6d02e30294cba03999.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6d02e30294cba03999.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://6d02e30294cba03999.gradio.live

# %% [markdown]
# 위의 코드는
#
# 3. 에러 핸들링: 사용자가 잘못된 입력을 했을 때, 예를 들어 허용되지 않은 개월 수를 입력하는 경우, 적절한 피드백을 제공하는 에러 핸들링이 필요한 것을 보완하여 만든 코드입니다.
#
# - 입력 검증 함수 (validate_input):
#
# validate_input 함수는 사용자가 입력한 개월 수가 허용된 개월 수(valid_months)인지 확인합니다. 만약 허용되지 않은 개월 수가 입력되면 False와 함께 잘못된 개월 수를 반환합니다.
#
#
# - 에러 처리 로직:
#
# chat_with_tutor 함수에서 사용자의 입력을 먼저 validate_input 함수로 검증합니다.
# 검증 결과 잘못된 입력이 확인되면, 사용자에게 올바른 개월 수를 안내하는 메시지를 반환하고, 추가적인 GPT 호출을 진행하지 않습니다.
#
#
# - 사용자 피드백 제공:
#
# 사용자가 허용되지 않은 개월 수를 입력할 경우, 적절한 안내 메시지를 통해 사용자가 다시 선택할 수 있도록 유도합니다.
# 이러한 수정 사항을 통해 사용자가 잘못된 입력을 했을 때 적절한 피드백을 제공함으로써 사용자 경험을 향상시킬 수 있습니다.
